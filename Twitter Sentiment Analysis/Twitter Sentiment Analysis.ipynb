# %%
import re
import nltk
import time
import tweepy
import pprint
import pickle
import numpy as np
from tweepy import OAuthHandler
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Initializing the API keys

#Consumer Keys
consumer_key = 'ZhP9aDb02I5o3Nz1dVMb7505D'
consumer_secret = 'HahRh4LjYgyjaIIw3rEj9vFP4OKgUSDywuHNGITMt18dUJ56eD'

#Generated API Tokens
access_token = '3221955110-A61i8EDWbHIEqnNzZgoUw9P0tOEGmUBstHjZNVa'
access_secret = 'CVDrSm34cwE3X1cp2bvPq87fZ0gAdv0iRmhYExnclCIjT'

# %%
#Client Authentication
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
#Setting up our search token
args = ['deeplearning']

#If it doesnot get any tweets then after 10sec it will timeout
api = tweepy.API(auth, timeout = 10)

# %%
#Fetching the top 100 recent Tweets
start = time.time()
list_tweets = []

#Lenght of args is always is 1
query = args[0]
if len(args) == 1:
    
    #Cursor is another class it is used to fetch the tweets
    #api.search because we are only search
    #q=query+" -filter:retweets" based on agrs[0] and we are filtering the same retweets
    #lang means we are only fetching english tewwts
    # result_type = 'recent' means we are looking for recent tweets
    for status in tweepy.Cursor(api.search, 
                                q=query+" -filter:retweets",
                                lang = 'en',
                                result_type = 'recent').items(500):
        list_tweets.append(status.text)
end = time.time()
print("Total Time Taken to fetch tweets: {}".format(end-start))
# Out:
# Total Time Taken to fetch tweets: 15.343263149261475

# %%
pp = pprint.PrettyPrinter(width=120, compact=True)
pp.pprint(list_tweets)
# Out:
# ['Reactions Home #DeepLearning #DataScience #MachineLearning  https://t.co/YKovQyDKFi',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? #DeepLearning #Medicine #fintech  '
#  'https://t.co/MzuHyEoRvz',
#  'Google Duplex AI Still Needs a Lot of Help From Humans #DeepLearning  https://t.co/m5OAUzHeAS',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/FiRqqfupIF',
#  '#datascience #machinelearning\n'
#  '#datascientists #BigData #data #tutorial #ArtificialIntelligence #deeplearning \n'
#  'Intro… https://t.co/Eb1WtgBbj7',
#  'iTunes &amp; Amazon paid music downloads\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/k9RNfdOPkU',
#  'Global recorded music industry revenues\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/8usRdAJBC5',
#  'The generation gap in music #streaming adoption\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/CGwvguvqZb',
#  '5 Ways to Turn Your LinkedIn Connections Into Paying Clients in 2019 https://t.co/YPGuJzuKa4 #socialmedia… '
#  'https://t.co/1jcYaONifx',
#  'Using deep learning for indoor autonomous navigation of a small quad-rotor. Need help with research '
#  'https://t.co/e230IJO82A',
#  'Automated Intent Classification Using Deep Learning https://t.co/bCYQc1FmiB  #DeepLearning',
#  'Reactions Home #DeepLearning #DataScience #MachineLearning  https://t.co/0KjeqLhn4X',
#  'So cool and sooooooo terrifying #deepfake #DeepLearning https://t.co/FpmvmVIhUU',
#  'Just today and tomorrow! Save 50% on our new MEAP Probabilistic Deep Learning with Python. Use code mlsicktw at… '
#  'https://t.co/5ODXsE5UiN',
#  'Metrics That Matter: Measuring the Effectiveness of Marketing Campaigns https://t.co/tfT64Y4gU5 #socialmedia… '
#  'https://t.co/nZ9UfB1zGO',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/bTTNwRPdO5',
#  '@deepgamingai explains how to use tensorflow’s #ObjectDetection model to play the classic FPS game Counter Strike:… '
#  'https://t.co/07YQsFMHoS',
#  '#DeepLearning affects a wide range of fields from #neuroscience to #socialmedia and more. https://t.co/a7GZ2LZzGE',
#  '8 Skills Every Small Business Marketer Needs in 2019 https://t.co/gba2w8ZmiS #socialmedia #digitalmarketing… '
#  'https://t.co/d1wj1InmjH',
#  'Heroes of Deep Learning: Geoffrey Hinton https://t.co/ynrdxaquow  #DeepLearning',
#  'The Future of eCommerce: 60 Stats and Trends for 2019 &amp; Beyond [Infographic] https://t.co/mXi6XFFKjc '
#  '#socialmedia… https://t.co/iVc2in4DzJ',
#  'ThreatsHub Cybersecurity News | Movie Tech Review: Child’s Play 2019 - https://t.co/iGUbazolD0 #CyberSecurity… '
#  'https://t.co/bUkwM0nokJ',
#  'ThreatsHub Cybersecurity News | Microsoft Outlook for Android Open to XSS Attacks - https://t.co/zvNQ6qLVrc… '
#  'https://t.co/mUfjRsCJj8',
#  'The 10 deeplearning Methods AI Practitioners Need to Apply\n'
#  'Interest in #machinelearning has exploded over the past… https://t.co/o5JtPtWrpm',
#  'In this episode, machine learning webinar series mention that how software engineers can switch their profession to… '
#  'https://t.co/k8Mgewd3hV',
#  'Insurance Analytics Market with Top Eminent Players Like IBM, Microsoft, Oracle, SAP SE, Salesforce, SAS Institute,… '
#  'https://t.co/1zV288EL5Y',
#  'Hey! Check out this service... June 22, 2019 at 12:45AM https://t.co/e5tEgCawB5 #Chelsea #MCICHE Aguer Sarri… '
#  'https://t.co/2GuTP2dQpz',
#  'Top influencers in artificial intelligence https://t.co/vFytupZ974 #socialmedia #digitalmarketing #contentmarketing… '
#  'https://t.co/7jbocaXV2m',
#  "Connecting Asia's startup ecosystem #DeepLearning #ArtificialIntelligence #AI  https://t.co/4CpIRi7p2m",
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/T0FVpD5cHM',
#  'Deep Learning Machine Shutting Off When Using Both GPUs https://t.co/SH97CnbyVe #machinelearning',
#  'Hello guys this is one of my project based on face recognition. https://t.co/fvCvVSGM7L #machinelearning',
#  'Building a CIFAR classifier neural network with PyTorch https://t.co/HO2Yw0t8xv #machinelearning',
#  'Giving my future reinforced neural network a little boost to learn to play a game https://t.co/6xH1FwMbd9 '
#  '#machinelearning',
#  'Course 3 of the https://t.co/vuGcshCRrN TensorFlow Specialization is now available: TensorFlow in Practice | Course… '
#  'https://t.co/YFvgp5E5Ur',
#  '[D] Any references for deep learning on non uniform and unstructured meshes/ grids? https://t.co/TZXWJvp7dv '
#  '#machinelearning',
#  'Generative Adversarial Networks - The Story So Far https://t.co/i2943qv8gm #machinelearning',
#  'Not sure if this is the correct thread, GPU related. https://t.co/IwOG110rOI #machinelearning',
#  'Canon Medical Receives FDA Clearance for Deep Convolutional Neural Network Image Reconstruction Technology for CT… '
#  'https://t.co/KH4TX1uX6p',
#  'Viral Trends: A Practical Guide for Marketers https://t.co/LXI9lWFz0S #socialmedia #digitalmarketing… '
#  'https://t.co/KU10qoPqWi',
#  'How Understanding Data Can Improve Your Customer Service #AI #CX #machinelearning #deeplearning… '
#  'https://t.co/mUgUMKkD74',
#  'How to Measure Your Facebook Return on Ad Spend https://t.co/yoyXAVOIjO #socialmedia #digitalmarketing… '
#  'https://t.co/48K2SpvJ3L',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? #DeepLearning #Medicine #fintech  '
#  'https://t.co/xLrkKVIzOZ',
#  'AI can help pathologists reduce their turnaround time in drug discovery\n'
#  'https://t.co/ckx9W3Hdt9\n'
#  '#deeplearning #ai… https://t.co/OoAIBCVZtf',
#  '#Ai #robotics #ml #DeepLearning they’re coming https://t.co/UOH5PSs591',
#  'Advanced Deep Learning with Keras: Apply deep learning techniques, autoencoders, GANs, variational autoencoders, de… '
#  'https://t.co/24ZQef5nM4',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/Gzv0ETeESj',
#  '#BigData: 3 ways to turn #BusinessIntelligence into a business advantage\n'
#  ' by @mark_samuels @ZDNet @burnettjulian |… https://t.co/KZfHBJ3moW',
#  'How to Recruit the Best AI Talent to Your Team\n'
#  '\n'
#  '#ai #machinelearning #deeplearning #artificialintelligence #bigdata… https://t.co/rhehFK1o5Q',
#  'HT KirkDBorne :\n'
#  '\n'
#  'Top-selling books in #AI and #MachineLearning: https://t.co/LEzaUbQ3Kv\n'
#  '...and more:… https://t.co/Ij7xPdwO9v',
#  '.@ark_aung does a fantastic job of bringing together some of the best resources that you need to jump into deep lea… '
#  'https://t.co/x5GJR8Yxoo',
#  'Machine learning and its scope — for core engineers, with a cup of coffee #DeepLearning #AI  https://t.co/JffPbtzMoY',
#  '10 Healthcare Quality Improvement Trends You Can’t Ignore https://t.co/0h6RHMJUPs\n'
#  '#Bigdata #Datascience #Tech… https://t.co/yLddqifBw3',
#  'Hey! Check out this service... June 21, 2019 at 11:45PM https://t.co/e5tEgCawB5 #Chelsea #MCICHE Aguer Sarri… '
#  'https://t.co/QxUXjEcnIO',
#  'Not as Deep as You Think #DeepLearning #MachineLearning  https://t.co/xeZ3q7GccZ',
#  'Productivity Confidential: Artificial Intelligence – Friend or Foe? (podcast) - Fast Company\n'
#  '\n'
#  'Read more here:… https://t.co/voHseQy4ss',
#  'Not as Deep as You Think #DeepLearning #MachineLearning  https://t.co/GHfTqHupzT',
#  "Connecting Asia's startup ecosystem #DeepLearning #ArtificialIntelligence #AI #MachineLearning  "
#  'https://t.co/N7Kd3wztjD',
#  'Global artificial intelligence market is expected to reach $71 billion by 2024 - Yahoo Finance\n'
#  '\n'
#  'Read more here:… https://t.co/CecgnGA0wm',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/gWjoEP0AeO',
#  'Researchers Develop #AI That Classifies Seizures Using Less Data\n'
#  '\n'
#  'https://t.co/4iSkaxJQWX by @Kyle_L_Wiggers v/… https://t.co/5gddPE1tox',
#  'The Future Of AI And Analytics Lies In Helping Small Businesses And Verticals Leverage The Cloud via @forbes… '
#  'https://t.co/u1cxTxtlYQ',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? #DeepLearning  https://t.co/LRMEDrDkMC',
#  'Deep Learning Prerequisites: The Numpy Stack in Python\n'
#  '\n'
#  '☞ https://t.co/ptkb6Xk0TU\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/8uySXXCSth',
#  'Deep Learning Prerequisites: The Numpy Stack in Python\n'
#  '\n'
#  '☞ https://t.co/eIz76GOCIU\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/Au8YfaCD5A',
#  'Insurance tech: should legacy applications stand in the way of innovation? - Finextra https://t.co/zWAu87j0ll… '
#  'https://t.co/NdoQmTDfUC',
#  'It is possible to personalize user experience, automate your processes and implement solutions that will give new m… '
#  'https://t.co/1rjqUmDZ90',
#  '#DeepLearning: What Is It Good For? Prof. Ankit Patel - @RiceUniversity\n'
#  '\n'
#  'More: https://t.co/cAK5ODBvhW… https://t.co/I3Ki1iOGqc',
#  'Death by #algorithm: \n'
#  '\n'
#  'the age of #KillerRobots is closer than you think \n'
#  '\n'
#  'https://t.co/uHbndGRt2W @voxdotcom… https://t.co/mLaai1a0L6',
#  'Social Network for Developers #DeepLearning #TensorFlow  https://t.co/FSut8A50d8',
#  'Why Swift may be the Next Big Thing #swiftlang #DeepLearning\n'
#  '#Python #tensorflow #machinelearning \n'
#  '#Swift \n'
#  'https://t.co/EzRpoigZjC',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/1ffqZKb1Ru',
#  '#AI re-defining the #FutureofWork &gt;&gt;&gt; WEF via MikeQuindazzi &gt;&gt;&gt; #ArtificialInteligence #Robotics '
#  '#IoT #DataScience… https://t.co/Ed7uDc2ixV',
#  'Not as Deep as You Think #DeepLearning #MachineLearning  https://t.co/e9xpZHQZSB',
#  '#AI re-defining the #FutureofWork &gt;&gt;&gt; @WEF via @MikeQuindazzi @darshan_h_sheth &gt;&gt;&gt; '
#  '#ArtificialInteligence #Robotics… https://t.co/sIg3cBhiHb',
#  '#AI re-defining the #FutureofWork &gt;&gt;&gt; WEF via MikeQuindazzi &gt;&gt;&gt; #ArtificialInteligence #Robotics '
#  '#IoT #DataScience… https://t.co/TdEGqJEMA3',
#  'How #MachineLearning Works [#INFOGRAPHICS] \n'
#  ' by @cbcurran @AnandSRao @PwC_LLP | \n'
#  '\n'
#  'Read more here:… https://t.co/iSxsDhvf44',
#  '#AI re-defining the #FutureofWork &gt;&gt;&gt; @WEF via @MikeQuindazzi &gt;&gt;&gt; #ArtificialInteligence #Robotics '
#  '#IoT… https://t.co/dFpeVCm6ip',
#  '“Within the next five years every single sector will begin to use #machinelearning, #AI and #deeplearning. The orga… '
#  'https://t.co/JyecQApzXb',
#  '“Within the next five years every single sector will begin to use #machinelearning, #AI and #deeplearning. The orga… '
#  'https://t.co/DRMfj6lPZz',
#  'This is creepy and amazing at the same time. Check out also the YouTube channel of @ctrl_shift_face, you will have… '
#  'https://t.co/bRJGtP4t6j',
#  'Reactions Home #DeepLearning #DataScience #MachineLearning  https://t.co/V91nBigZmv',
#  '#TechStuff: Python leads the 11 top Data Science, Machine Learning platforms: Trends and Analysis\n'
#  '\n'
#  '#datascience #ai… https://t.co/ddfJRO8Wyu',
#  "Connecting Asia's startup ecosystem #ArtificialIntelligence #DeepLearning #AI  https://t.co/21coyyj8dy",
#  'Hey! Check out this service... June 21, 2019 at 10:45PM https://t.co/e5tEgCawB5 #Chelsea #MCICHE Aguer Sarri… '
#  'https://t.co/E24ZzYMjDs',
#  '#Data #Science Hackathon: Win Prizes By Using #Machine #Learning To #Predict Value Of Used #Cars\n'
#  '#futureready… https://t.co/OLWSi9WGPC',
#  'Reactions Home #DeepLearning #DataScience #MachineLearning  https://t.co/5Nprto5Iq2',
#  'Best paper s\n'
#  'The 2019 IEEE Conference on Computer Vision and Pattern Recognition  @cvpr2019\n'
#  '@CVPR… https://t.co/zeblvPAeTy',
#  'NTPC to expedite #training of #executives using #machine #learning, #AI\n'
#  '\n'
#  '#artificailintelligence #onlinecourse… https://t.co/Msrs9DoZfL',
#  'Global artificial intelligence market is expected to reach $71 billion by 2024 - GlobeNewswire\n'
#  '\n'
#  'Read more here:… https://t.co/Luu2Et1d6p',
#  'vRT @IainLJBrown Global artificial intelligence market is expected to reach $71 billion by 2024 - Yahoo Finance Rea… '
#  'https://t.co/QaBmJwEHVT',
#  '[1906.07343] Language as an Abstraction for Hierarchical Deep Reinforcement Learning https://t.co/xPlgRC9vrW… '
#  'https://t.co/FzTxf2rgla',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/JB4Xe9Bxfv',
#  'Want to change your life and career in just 6 weeks? Welcome to Magnimind Academy. https://t.co/lBSm5DjL6S… '
#  'https://t.co/ixvfUd9Wa1',
#  'Implement artificial intelligence to give a huge boost to your #business.\n'
#  'https://t.co/xkwY719Xi0… https://t.co/tW1tJhBMTi',
#  'New Amax servers aim to accelerate AI and ML workflows\n'
#  '_____\n'
#  '#MachineLearning #AI #DeepLearning #abdsc… https://t.co/GYsewqAJHG',
#  'Top-selling books in #AI and #MachineLearning:  https://t.co/dkBWTc8xOv\xa0 \n'
#  '...and more: https://t.co/LndVL0TgKp\xa0\n'
#  '———… https://t.co/BFBFBmmLNi',
#  'Top-selling books in #AI and #MachineLearning:  https://t.co/uwpA7exmcm\xa0 \n'
#  '...and more: https://t.co/9gDWddK2BC\xa0\n'
#  '———… https://t.co/scc6MtgTeu',
#  'Top-selling books in #AI and #MachineLearning:  https://t.co/gOrdqTeeIS\xa0 \n'
#  '...and more: https://t.co/dEGCxON6JO\xa0\n'
#  '———… https://t.co/lRIdjhmIKH',
#  'White House Updates \n'
#  '\n'
#  'National #ArtificialIntelligence Strategy \n'
#  '\n'
#  'https://t.co/JX3SHJewuE #fintech #AI… https://t.co/X1W4SoivMI',
#  "Connecting Asia's startup ecosystem #DeepLearning #ArtificialIntelligence #AI #MachineLearning  "
#  'https://t.co/C7bwNiCwBl',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/FOwfgE59gm',
#  'At Redis Conf 2019, Redis Labs introduced a new module, RedisAI. The idea is that Redis wants to bring together mac… '
#  'https://t.co/QnwtHUYE9q',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? #DeepLearning #Medicine #fintech  '
#  'https://t.co/SMlG6L3XAn',
#  'Reactions Home #BigData #DataScience #MachineLearning #DeepLearning  https://t.co/CzLlvLZy4B',
#  'Latest Four Hidden Methods To Make Cash Via Revenue And Advertising Training #small#business #luxurycars #marketing… '
#  'https://t.co/zgNbCt1dqA',
#  'Alessandro Blassime/ETH Zurich on Digital Helath Information on the ethical aspects of digital technology on… '
#  'https://t.co/2RgyCjj4k2',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? | #ai #deeplearning #medicine #healthcare '
#  'https://t.co/T3PADLs1xW',
#  'Very insightful presentation by @a_blasimme on #ethics in #digitalhealth, with #philosophical comparison of… '
#  'https://t.co/ZWdKfA6Ytw',
#  'AND we come to the end of an awesome talk by @drsrinip on #AI is eating the world. The audience thoroughly enjoyed… '
#  'https://t.co/UXvfhlUkfv',
#  'Deep Learning method for railway and train detection\n'
#  '\n'
#  'Follow me for more: https://t.co/osWqILvTof… https://t.co/XloeE4jsW3',
#  'What do you think about #SEO?\n'
#  '#reason78toworkwithalea- Expert #seomarketing\n'
#  '#ai #iot #machinelearning #bigdata… https://t.co/hvS1ayhaHR',
#  'Hey! Check out this service... June 21, 2019 at 09:45PM https://t.co/e5tEgCawB5 #Chelsea #MCICHE Aguer Sarri… '
#  'https://t.co/4xqLahNM9K',
#  '@NetcoreSolution India  will win\n'
#  '\n'
#  '#INDvAFG #WC2019 #AI #marketingautomation #deeplearning \n'
#  'Netcore Solutions\n'
#  'Tag fr… https://t.co/YEetyeDNmB',
#  'Instagram Marketing: 4 Features You Should Be Using [Examples] https://t.co/amq3JWosai #socialmedia… '
#  'https://t.co/fi7TBbtttX',
#  'Enhancing #facerecognition tools with generative face completion  #deeplearning #machinelearning… '
#  'https://t.co/7f7qzeG77F',
#  'As Deep Learning Comes For Medicine How Do We Work Around Its Brittleness? #Fintech #DeepLearning #Medicine  '
#  'https://t.co/X8VwC4zgYS',
#  'U.S. recorded music revenues by format\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/J5uD4aFxn4',
#  'How the web has changed the way we buy #music\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/Viu2usHBeU',
#  'Pressure mounting on insurers to tackle silent cyberrisk - S&amp;P Global Platts https://t.co/FBK2rJ2MYq\n'
#  '\n'
#  '#DataScience… https://t.co/j7ymfq9IsM',
#  'Scientists use machine learning to improve gut disease diagnosis: Machines use Google-type algorithms on biopsy ima… '
#  'https://t.co/1FlhaLqwVg',
#  'Artificial intelligence has recently become the focus of the public after three ups and downs. With the rapid devel… '
#  'https://t.co/gr0tLGBnJu',
#  '#Opinion | #ArtificialIntelligence needs to become less and less #artificial\n'
#  '\n'
#  'https://t.co/RN3NEyWeUg\n'
#  '#ai #ml… https://t.co/YYHgDQFAWm',
#  'AI brings #opportunity and #risk \n'
#  '\n'
#  'to the health sector \n'
#  '\n'
#  'https://t.co/CFyBOi08mw #fintech #insurtech #healthcare… https://t.co/BNgRC0qM4J',
#  '“Your academic education is going to land you a job. Your self-learning is going to make you wealthy.”… '
#  'https://t.co/Tt61M8IguV',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/KAr1uRC2mu',
#  'Amazon: Art of the possible- Leveraging Machine Learning to Improve Forecasting and Governance -… '
#  'https://t.co/BMp4zOvSCw',
#  'Getting Started With Deep Learning: Using Keras &amp; Numpy To Detect Voice Disorders - Liwaiwai #DeepLearning… '
#  'https://t.co/zk0C21d4cU',
#  "#Dogs saves us from #disaster, it's time for #machines to save us from disaster!👍 #AI #ML #DeepLearning… "
#  'https://t.co/XX6Zif4jDH',
#  'Getting Started With Deep Learning: Using Keras &amp; Numpy To Detect Voice Disorders - Liwaiwai #DeepLearning… '
#  'https://t.co/5InmVpuwC4',
#  'Learning #AI for Product Managers:  https://t.co/I2aCYr8Lbh\xa0 \n'
#  '——————\n'
#  '#BigData #DataScience #MachineLearning… https://t.co/OBc7y58O1M',
#  '“#DeepLearning Cheat Sheets #KDN https://t.co/tfGh9sXb5u” https://t.co/qeQsRVSQ1Q',
#  'Learning #AI for Product Managers:  https://t.co/KuTrelqeIC\xa0 \n'
#  '——————\n'
#  '#BigData #DataScience #MachineLearning… https://t.co/B9KYGFGYFd',
#  'Learning #AI for Product Managers:  https://t.co/6wFhxsXqCv\xa0 \n'
#  '——————\n'
#  '#BigData #DataScience #MachineLearning… https://t.co/UmabFn89Km',
#  'Deep learning for cellular image analysis | Nature Methods https://t.co/AEMuHfROHc  #DeepLearning',
#  "Report sees peril in #cybercriminals' looming \n"
#  '\n'
#  'use of #AI \n'
#  '\n'
#  'https://t.co/I6jms3CUVD #fintech #insurtech… https://t.co/EUJaOdLe2r',
#  'How #deeplearning can identify/extract meaning from an image with text through Feature Extraction method. #AI… '
#  'https://t.co/0lDjfgnVms',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/Z98xvyHJrn',
#  'Deep Learning: Advanced NLP and RNNs\n\n☞ https://t.co/lQpRUA0vRf\n\n#DeepLearning #ai https://t.co/3uITa2qjZd',
#  'Deep Learning: Advanced NLP and RNNs\n\n☞ https://t.co/7EgTO2xyKq\n\n#DeepLearning #ai https://t.co/kZt5sBQzBF',
#  '#DeepLearning, Part 1: Not as Deep as You Think\nhttps://t.co/z7ysojHga0\n#MachineLearning https://t.co/aUIwRCYTLC',
#  'Easy way to convert categorical values to Numbers in Python using pandas.\n'
#  '\n'
#  '#Data #Machinelearning #Deeplearning… https://t.co/ZL3BGEOlNw',
#  'As #DeepLearning Comes For #Medicine \n'
#  '\n'
#  'How Do We Work Around Its Brittleness? \n'
#  '\n'
#  'https://t.co/CLxVqYMDIB #fintech… https://t.co/8Rfvw4lTT7',
#  'Also for day 70 of #100DaysOfMLCode a good podcast by @datafuturology with Dr. Eric Daimler @ead… '
#  'https://t.co/uCi4f1H224',
#  'Deep Learning Prerequisites: Linear Regression in Python\n'
#  '\n'
#  '☞ https://t.co/8YtijpQ8pI\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/8ee5R6w9bB',
#  'We use Artificial Intelligence to predict cryptocurrency market movements  @aiprofit #artificialintelligence… '
#  'https://t.co/sNqOuZ1lj7',
#  'Understanding Deep Learning through Neuron Deletion https://t.co/cW2jCEpEBi  #DeepLearning',
#  'Deep Learning Prerequisites: Linear Regression in Python\n'
#  '\n'
#  '☞ https://t.co/Fki5luTtAo\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/1yvB9kRQRn',
#  'Artificial Intelligence Influencers\n'
#  '@mikequindazzi\n'
#  '@ipfconline1\n'
#  '@alvinfoo\n'
#  '@juliosilvajr\n'
#  '@ronald_vanloon\n'
#  '@enkronos… https://t.co/pRkB678Mi2',
#  'Reactions Home - Reactions https://t.co/IArVrHHnp0\n'
#  '\n'
#  '#DataScience #MachineLearning #DeepLearning #Insurance #NLP #Robots #AI #IoT #BigData',
#  'https://t.co/7LbuhqoN5d is a decentralized #stock exchange (broker) using multi factor systems &amp; #deeplearning '
#  'to c… https://t.co/LnS6HDvLuF',
#  'The year 2019 has arrived, but the wave of artificial intelligence has not subsided. A number of national strategic… '
#  'https://t.co/R18NDlElHa',
#  'Cray Powers Geospatial AI Revolution With Breakthrough Deep Learning Performance https://t.co/0G8ePFxuxh… '
#  'https://t.co/R0622zGWLS',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/TARdDH1biK',
#  'Top-selling books in #AI and #MachineLearning: https://t.co/4gfQKlTbV5 \n'
#  '...and more: https://t.co/miqWq4YBJi\n'
#  '—————… https://t.co/PUNsfO7MAb',
#  '#DeepLearning Vs Deep Reinforcement Learning Algorithms in Retail Industry\u200a—\u200aII https://t.co/6eV8lrGHuo '
#  'https://t.co/QsF2xSBKCT',
#  'We are starting today new @twimlai online study group for the NLP course CS224N by @StanfordOnline. Join us and be… '
#  'https://t.co/8R1IE2aSwo',
#  'The Deep Learning AI Playbook: Strategy for Disruptive Artificial Intelligence https://t.co/6fbE22NXRB #DeepLearning '
#  '#AI',
#  'OpenText: Tapping your stores of unstructured data can yield new insights… - https://t.co/DagTBVMroY #OpenText… '
#  'https://t.co/lElIIk4Wto',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/KMGE9F46aB',
#  'How to Become a Great CDO\n'
#  '\n'
#  '#ai #machinelearning #deeplearning #artificialintelligence #bigdata #datascience… https://t.co/yCYmIFcLzq',
#  'Our paper titled "Stealing Neural Networks via Timing Side Channels" has been accepted at International Conference… '
#  'https://t.co/xIKTY2hvMW',
#  'Global artificial intelligence market is expected to reach $71 billion by 2024 - GlobeNewswire\n'
#  '\n'
#  'Read more here:… https://t.co/ndOf5T0uY1',
#  'God (light) comes to us not through ceremonies n good times. He comes into a pained heart n tuff times… '
#  'https://t.co/IVjnJ72XAR',
#  '8 Actionable Takeaways from the 2015 SEO Ranking Factors\n'
#  '#AI #AR #VR #Blockchain #Drones #Robotics #IoT #3Dprinting… https://t.co/aIcnixz9Rl',
#  'DeepFake Buster : AI beating AI, really cool! #DeepLearning  https://t.co/SOj5jGepz0',
#  'Reinforcement Learning with Pytorch\n\n☞ https://t.co/SYnMGnKsM6\n\n#DeepLearning #ai https://t.co/dFZQif2hS9',
#  'Reinforcement Learning with Pytorch\n\n☞ https://t.co/kTilgj9pyj\n\n#DeepLearning #ai https://t.co/7OMFUyvRld',
#  'MIT Teaching Robots to Combine Sight and Touch https://t.co/ucUfDL3N1v #DeepLearning #MachineLearning #AI… '
#  'https://t.co/1ypnSL12em',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/uWmrC67vHS',
#  'Modernizing Insurance Data Platforms to Improve Governance and Enrich Customer Experience - Gigaom… '
#  'https://t.co/bABNW5dLgR',
#  'Not sure if this is the correct thread, GPU related. https://t.co/6kgEnVl3nQ',
#  'The innovation startup #DeepLearning #artificialintelligence #ai #machinelearning  https://t.co/vsDXnTFmHx',
#  '@NetcoreSolution Indiaaaa....... Indiaaaa.......\n'
#  'INDIA will win the match \n'
#  '@NetcoreSolution \n'
#  '#INDvAFG #WC2019 #AI… https://t.co/jo0FVz21mR',
#  '#RegTech wants to improve behavior monitoring w/ #AI &gt;&gt;&gt; #PwC via MikeQuindazzi &gt;&gt;&gt; #FinTech '
#  '#Insurtech #IoT… https://t.co/hCxzpwInaa',
#  '#RegTech wants to improve behavior monitoring w/ #AI &gt;&gt;&gt; #PwC via MikeQuindazzi &gt;&gt;&gt; #FinTech '
#  '#Insurtech #IoT… https://t.co/Wv2LZRjsal',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/sURrfnH0qL',
#  '#RegTech wants to improve behavior monitoring w/ #AI &gt;&gt;&gt; #PwC via @MikeQuindazzi &gt;&gt;&gt; #FinTech '
#  '#Insurtech #IoT… https://t.co/z7IloRDkrh',
#  'Asia Times | AI accelerates development of limitless fusion energy | Article https://t.co/AxZwVnKjAV #DeepLearning… '
#  'https://t.co/IXLNjqkMxN',
#  'Open-domain question answering with DeepPavlov – DeepPavlov – Medium https://t.co/e931BlEBsG #DeepLearning… '
#  'https://t.co/nOFmQNosyO',
#  'And Now This:  Understanding Deep Learning - https://t.co/AD696wlmNl\n'
#  '\n'
#  '#tech #technology #datascience… https://t.co/xTdC23DEyZ',
#  'How to design AI tools for the workplace, according to #Google  https://t.co/I0n5TFAYu5\n'
#  '\n'
#  '#AI #machinelearning #nlp… https://t.co/rpgArrLIxq',
#  'AhrvoDEEX is a decentralized #stock exchange (broker) using multi factor systems &amp; #deeplearning to create '
#  'equity s… https://t.co/lOoH48eid1',
#  '@FarmersWeeklyNZ We have had a tremendous response to this article and many offers to assist #sheepNN #DeepLearning… '
#  'https://t.co/rUK25mmEDY',
#  'Simple Introduction to Neural Networks – Towards Data Science https://t.co/qagPn2b3SV #DeepLearning… '
#  'https://t.co/fje72prWkD',
#  'How Do You Define Unfair Bias in Artificial Intelligence? @ColinAPriest @DataRobot #AI #MachineLearning… '
#  'https://t.co/BUwZuCCjm9',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/tgbbjrCgWn',
#  "Artificial Intelligence, Spotting 'Fake News,' and Digital Equity: What to See at ISTE 2019 - Education Week\n"
#  '\n'
#  'Read… https://t.co/SOSv4Ft1dA',
#  'Business leaders have written a letter urging the next prime minister to commit to completing HS2. #deeplearning… '
#  'https://t.co/Qqi1uhzJR3',
#  'How scientists are fighting back against the coming deepfake sh*t-show #deepfake #NeuralNetworks #DeepLearning  '
#  'https://t.co/5FSER3vstp',
#  'Looking forward to our very first #DevSprint with students. So excited about the young speakers that will be sharin… '
#  'https://t.co/gFdvjy4UGR',
#  'How #Blockchain Can Transform #ArtificialIntelligence\n'
#  'by @dash_bouquet @hackernoon |\n'
#  '\n'
#  'https://t.co/zAa1A4N0q6\n'
#  '\n'
#  '#AI… https://t.co/v1tXcCyVOn',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/uqeii1yw23',
#  'The History, Evolution and Growth of #DeepLearning\n'
#  '\n'
#  'https://t.co/1spmPuSBzl   via @analyticsinme\n'
#  '#AI… https://t.co/xkF4FkSNyS',
#  "Top story: @Ronald_vanLoon: 'A new mind-set for the no-collar workforce [#INFOGRAPHICS]\n"
#  ' via @Fisher85M |… https://t.co/TXN1WJNMeg',
#  'Deep Learning for Student Competitions https://t.co/sjdC0cMAiJ  #DeepLearning',
#  'Online Courses - Complete 2019 Data Science &amp; Machine Learning Bootcamp -&gt; https://t.co/5lCyYUXgOT… '
#  'https://t.co/g4OlN9HT7D',
#  'Artificial Intelligence Explained: What Are Generative Adversarial Networks (GANs)? https://t.co/Z4SxknYtbu #AI #ML… '
#  'https://t.co/xn89BzpftP',
#  '#Robotic arm learns to fly Boeing 737 via #AI software.\n'
#  '\n'
#  '⚡ via @MikeQuindazzi\n'
#  '\n'
#  '#AI #Robotics #Autonomous… https://t.co/dT1CFsIkAX',
#  "I'm going through a process where my own mind is lying to me. Don't believe it's true? Check out Marvin Minsky  "
#  '"so… https://t.co/YKlQijtxn3',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/q1R5lpheMS',
#  'I have many questions...how recent were the mammograms? From the same imaging manufacturers or different? #AI goes… '
#  'https://t.co/FglKZfQeZ9',
#  'Machine learning and its scope — for core engineers, with a cup of coffee\n'
#  'https://t.co/DJtlmibBa4\n'
#  '+1 Hal2000Bot #AI #deeplearning',
#  'Cloud-based Image Classification Service Is Not Robust To Simple Transformations: A Forgotten Battlefield… '
#  'https://t.co/cx0zdmQEE3',
#  'Sample #FinTech landscape, by type and segment &gt;&gt;&gt; StatistaCharts via MikeQuindazzi &gt;&gt;&gt; #AI '
#  '#MachineLearning… https://t.co/0sVQawcC8t',
#  'Free Coupons Discount - SQL - MySQL for Data Analytics and Business Intelligence Courses -&gt; '
#  'https://t.co/IYImRMK0ld… https://t.co/kG7Bdt0ABU',
#  "Top story: @Ronald_vanLoon: 'A new mind-set for the no-collar workforce [#INFOGRAPHICS]\n"
#  ' via @Fisher85M |… https://t.co/NoEufe4XoA',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/NyxpSy2G0U',
#  'Sample #FinTech landscape, by type and segment &gt;&gt;&gt; @StatistaCharts via @MikeQuindazzi &gt;&gt;&gt; #AI '
#  '#MachineLearning… https://t.co/3NPXSiYqe1',
#  'Artificial Intelligence Generates Humans’ Faces Based on Their Voices  https://t.co/g6ympmUfDC #AI #ML #DL… '
#  'https://t.co/H0CVVoEXMF',
#  'Not enough labeled training data is a huge barrier for the efficiency of #deeplearning\n'
#  '\n'
#  '👉 Here are 5 strategies for… https://t.co/njuRrgg7vp',
#  'Distributed Deep Learning Pipelines with PySpark and Keras https://t.co/MfGiaJPefv by @TDataScience #deeplearning',
#  'Udemy Free Discount - Deep Learning with TensorFlow 2.0 [2019] #udemycoupon &gt; https://t.co/vz4Tk3Wed7\n'
#  '\n'
#  '#DataScience… https://t.co/vO956hviX1',
#  'New Online Courses - Data Science: Deep Learning in Python -&gt; https://t.co/0W1vqE0qMD  \n'
#  '\n'
#  'Explore #Python… https://t.co/WxTjIF4wfw',
#  'ThreatsHub Cybersecurity News | This Week in Security News: Cyberespionage Campaigns and Botnet Malware -… '
#  'https://t.co/ma0JFrNJd0',
#  'ThreatsHub Cybersecurity News | MobOk Malware Hides in Photo Editors on Google Play, Siphons Cash -… '
#  'https://t.co/CFeBpVQ1K7',
#  'Why #ArtificialIntelligence Is About to Make \n'
#  '\n'
#  '#Ransomware #HackAttacks Even Scarier \n'
#  '\n'
#  'https://t.co/yn3u3s1gRi… https://t.co/u0FfihxMFg',
#  'MIT Deep Learning Basics: Introduction and Overview with TensorFlow\n'
#  '\n'
#  '☞ https://t.co/pk0tDyI5Ve\n'
#  '\n'
#  '#DeepLearning… https://t.co/xs1zojJ6RE',
#  'MIT Deep Learning Basics: Introduction and Overview with TensorFlow\n'
#  '\n'
#  '☞ https://t.co/pWt0eM62QZ\n'
#  '\n'
#  '#DeepLearning… https://t.co/HhZMzuAEEl',
#  'A Beginner’s Guide To Generative Adversarial Networks(GANs) https://t.co/6nmwfmDCom #DeepLearning #MachineLearning… '
#  'https://t.co/qJEGeU2Jkf',
#  'Making Deep Learning Useful for Small Life Science Datasets https://t.co/M0T6i5TYes  #DeepLearning',
#  '#AI storage: #MachineLearning #DeepLearning and #storage needs https://t.co/Y5g5JiInGI via @SwissCognitive… '
#  'https://t.co/RCQh3Jjg36',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/qUgloF78Bi',
#  'Artificial intelligence, a primer for physicians https://t.co/MGD0W9AeCv\n'
#  '#AI #MachineLearning #DeepLearning… https://t.co/ZNEBi9ik3p',
#  'Put Down The Deep Learning: When Not To Use Neural Networks And What To Do Instead - Liwaiwai #NeuralNetworks… '
#  'https://t.co/fn7OJyWfjy',
#  'The Dirty Expensive Secret \n'
#  '\n'
#  'of #ArtificialIntelligence and #MachineLearning \n'
#  '\n'
#  'https://t.co/ZMVv7WGCkR #fintech #AI… https://t.co/xflj8eFLKd',
#  'CloudEXPO New York Spring 2020 Sponsorship Opportunities Open! \n'
#  '\n'
#  '#HybridCloud #BigData #AI #IoT #SmartCities #AIOps… https://t.co/1hio87ezpR',
#  'Keras Tutorial: Deep Learning in Python https://t.co/WQllJ1m4pw  #DeepLearning',
#  '🤖👍🏻 Another triple for the DeepRacer League brings more world records and the first female winner!… '
#  'https://t.co/qOJgbyvhEn',
#  '#Deeplearning enables high-quality and high-throughput prediction of enzyme commission numbers #LifeSciences… '
#  'https://t.co/sa7NuyuoKI',
#  'How #Google uses #ReinforcementLearning \n'
#  '\n'
#  'to Train #AI Agents in the Most Popular #Sport in the World… https://t.co/tR85dyjX5L',
#  'Calibrated Model-Based Deep Reinforcement Learning #DeepLearning #Statistics  https://t.co/GtpxCAMl9b',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/sW8QiNTJlj',
#  'DigiTrax A.I. blockchA.I.n music https://t.co/YPEJJ4KiWH #ML #MachineLearning #AI #ArtificialIntelligence… '
#  'https://t.co/58M4zwKUQW',
#  'KR38R Beats sets the stage for the future of hip hop production https://t.co/v6KpAPlcl2 #beats #music #hiphop #trap… '
#  'https://t.co/bcv2kTrs1l',
#  'Hiring a Great Technical Sales Manager\n'
#  '\n'
#  '#ai #machinelearning #deeplearning #artificialintelligence #bigdata… https://t.co/6dVjggdTLY',
#  "So, Google is now able to do speech-speech language translation directly without using text. That's neat. Good job… "
#  'https://t.co/Z1eB678h7f',
#  'Aon targets improved customer engagement with Hi Marley partnership - Reinsurance News https://t.co/CS0OLliUAD… '
#  'https://t.co/lpzvl7Zkm2',
#  'Google’s latest #LanguageMachine \n'
#  '\n'
#  'puts emphasis back on #language \n'
#  '\n'
#  'https://t.co/KL3ZyqUEFn #fintech @ZDNet… https://t.co/0ryTmf7GXi',
#  'Deepfake 3.0 (beta), the bad news: This AI can turn ONE photo of you into a talking head. Good news: There is none… '
#  'https://t.co/w1ZHoUTZI0',
#  'Alexa Gone Bad: \n'
#  '\n'
#  'When #AI #Assistants Turn On Us \n'
#  '\n'
#  'https://t.co/vnfaq3YFRe #fintech #cybersecurity #Iot… https://t.co/piOgCab7fR',
#  '#DeepLearning has made it easier for anyone to forge convincing misinformation. But just how easy? Researchers at G… '
#  'https://t.co/f4yKF6IXuL',
#  'ThreatsHub Cybersecurity News | Data of 645k Oregonians exposed after nine DHS employees fell for a phishing attack… '
#  'https://t.co/w2QBmSWDKu',
#  "ThreatsHub Cybersecurity News | Digi-dosh exchange Coinbase: Someone tried to pwn our staff via this week's Firefox… "
#  'https://t.co/jRSXO7DNci',
#  'Ensemble Machine Learning in Python: Random Forest, AdaBoost\n'
#  '\n'
#  '☞ https://t.co/ffliEifXez\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/xFrqePxLH5',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/pI95FbxElM',
#  'Ensemble Machine Learning in Python: Random Forest, AdaBoost\n'
#  '\n'
#  '☞ https://t.co/2LewBvz0sX\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/jhCZZKwIIx',
#  '2019 Games for Change Festival: Deep Learning Through Games https://t.co/FE5H1ArnpR  #DeepLearning',
#  'Policy Expert forays into motor insurance - Insurance Business UK https://t.co/j4sNLMhNTZ\n'
#  '\n'
#  '#DataScience… https://t.co/khSUC3RvDH',
#  'Oasis Loss Modeling Framework Available On Fractal Advanced Insurance Decision Platform - PRNewswire… '
#  'https://t.co/vybSY866Yl',
#  'Driving value from AI in insurance: Delivering success with Sun Life and Scotiabank - Insurance Business Canada… '
#  'https://t.co/k8UEiqWznc',
#  'New Analysis Report on Insurance IT Spending Market 2024 - Market Research Updates https://t.co/zGZWX6IlZi… '
#  'https://t.co/EmmTzYKkgW',
#  'CVPR 2019 showcased #AI that can #visualize \n'
#  '\n'
#  '#hidden #objects and see around corners \n'
#  '\n'
#  'https://t.co/O7X7XNDf79… https://t.co/1gR89M2qsk',
#  'HT KirkDBorne :\n'
#  '\n'
#  'See how IBM’s #AI automatically generates creative captions for images: https://t.co/32l5xVgVGA by… '
#  'https://t.co/nh2lcK1lUV',
#  'See how IBM’s #AI automatically generates creative captions for images: https://t.co/fcw4kWzVmC by @Kyle_L_Wiggers… '
#  'https://t.co/zXYYs6EjS3',
#  "Why #DigitalTransformation Won't Succeed Without Cultural Change\n"
#  ' by @naullyn |\n'
#  '\n'
#  'https://t.co/g54kGNTJzY \n'
#  '\n'
#  '#Digital… https://t.co/irn0nJvn5t',
#  'Bring on the #AI #revolution \n'
#  '\n'
#  '&amp; its shake-up of #academia \n'
#  '\n'
#  'https://t.co/KUjvip8MmF #fintech #insurtech… https://t.co/2EEVPmwbXc',
#  'Linear Regression — Dive into #DeepLearning\n'
#  '\n'
#  'https://t.co/jFkbCUvV0d \n'
#  '#AI #MachineLearning #DataScience\n'
#  'Cc… https://t.co/jdNaQR2HMz',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/a2ihsHOsWP',
#  'How to use the Alexa app in Windows 10\nhttps://t.co/HoaYUxr4uz\n+1 Hal2000Bot #AI #deeplearning',
#  'AI &amp; Deep Learning Summits in San Francisco, what did you miss? https://t.co/avHbgrftwu #deepLearning #ai '
#  '#artificialIntelligence',
#  'Researchers teach #AI \n'
#  '\n'
#  'to write haikus \n'
#  '\n'
#  'https://t.co/2b7IE6xE4Z #fintech #ArtificialIntelligence #MachineLearning… https://t.co/Mb8v07L3OH',
#  'Introducing Deep Spreadsheets with #XLNet - state of the art deep learning in excel! #HappyFriday\n'
#  '\n'
#  '#DeepLearning… https://t.co/ZQT2wWXmYv',
#  '#MachineLearning engineers get passionate about that python library.\n'
#  '\n'
#  '#datascience #deeplearning #ai… https://t.co/xHFk1hCTst',
#  'Extracting campaign finance data from gnarly pdfs using #deeplearning https://t.co/HfcidLscfF '
#  'https://t.co/oRy8OxjDeg',
#  'AI Can Now Detect Deepfakes by Looking for Weird Facial Movements\n'
#  'https://t.co/GXpzyQ5APS\n'
#  '+1 TechBot #AI #deeplearning',
#  'ABC: Free Datasets for Geometric Deep Learning – AI³ | Theory, Practice, Business – Medium https://t.co/GeSu8sg9Ao… '
#  'https://t.co/X4SYpi3jMa',
#  'Getting Started With Deep Learning: Using Keras &amp; Numpy To Detect Voice Disorders - Liwaiwai #DeepLearning… '
#  'https://t.co/EFN6KBOu4r',
#  'How to design #AI #tools \n'
#  '\n'
#  'for the #workplace, according to #Google \n'
#  '\n'
#  'https://t.co/1P2CwyuVMi #fintech #insurtech… https://t.co/o4uJQ0ferA',
#  'How Understanding Data Can Improve Your Customer Service #AI #CX #machinelearning #deeplearning… '
#  'https://t.co/5PanEQ4jJf',
#  'Train and deploy Keras models with TensorFlow and Apache MXNet on Amazon SageMaker\n'
#  '\n'
#  '#MachineLearning #DeepLearning… https://t.co/1ezzs7jGoV',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/jBLci19m3I',
#  'AM Best Downgrades Credit Ratings of ARABIA Insurance Company - Jordan - Business Wire https://t.co/28AuEwSkHa… '
#  'https://t.co/wQqElE0keC',
#  'Jeff Scheaffer relates some of the applications Cisco is using with various AI related tools.… '
#  'https://t.co/hphUiDTVVP',
#  'Spotting objects amid clutter \n'
#  '\n'
#  'Conventional techniques that try to pick out objects from such clouds of dots, or p… https://t.co/VVQYxIFENH',
#  'HT KirkDBorne :\n'
#  '\n'
#  'Learning #AI for Product Managers: https://t.co/YxRmnhUdsg\n'
#  '——————#BigData #DataScience… https://t.co/0EB4r0RJOa',
#  'Word(s) of the day: Artificial Intelligence. Check out our apparel!! #datascience #artificialintelligence… '
#  'https://t.co/HdQlTVJJGh',
#  'AI and #DeepLearning for Automotive Applications. #BigData #Analytics #MachineLearning #DataScience #AI #IoT #IIoT… '
#  'https://t.co/wDypheqIH1',
#  'Learning #AI for Product Managers: https://t.co/zObQa5w0IQ \n'
#  '——————\n'
#  '#BigData #DataScience #MachineLearning… https://t.co/JZSoHxZIWb',
#  'A new set of images that fool #AI \n'
#  '\n'
#  'could help make it more #HackerProof \n'
#  '\n'
#  'https://t.co/3IdM35RtRH #fintech… https://t.co/5c01PbzvQf',
#  "#AmazonFashion's New #VisualSearch Tool Aims to Boost Apparel Sales https://t.co/ZoXEs95Cg8 #StyleSnap #Fashion… "
#  'https://t.co/Jv8k9vmh82',
#  'Put Down The Deep Learning: When Not To Use Neural Networks And What To Do Instead - Liwaiwai #NeuralNetworks… '
#  'https://t.co/bZo5cj8x7U',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/UwbBPUqFnP',
#  'Illustrated Guide to LSTM’s and GRU’s. #BigData #Analytics #DeepLearning #MachineLearning #DataScience #AI #IoT… '
#  'https://t.co/0l6XDmOKGK',
#  'Data Pre-processing for Deep Learning models (Deep Learning with Keras - Part 2) #deeplearning '
#  'https://t.co/yf5NHl5UVA',
#  'HT KirkDBorne :\n'
#  '\n'
#  'This week’s featured articles and resources in #MachineLearning #DataScience #AI #Statistics and m… '
#  'https://t.co/jbvHccGo3Z',
#  '#TechStuff: Microsoft to train 1.5 lakh students at AI digital labs in India - THE WEEK\n'
#  '\n'
#  '#ai #ml #neuralnetworks… https://t.co/6aWgFVJoA1',
#  'This week’s featured articles and resources in #MachineLearning #DataScience #AI #Statistics and more at… '
#  'https://t.co/iJaVm9XcL4',
#  'YOLO Object Detection in MATLAB, Start to Finish – Towards Data Science https://t.co/7gzbvOCsLV #DeepLearning… '
#  'https://t.co/Qmf9swGzQk',
#  'Good one for federated learning! #MachineLearning #DeepLearning #ArtificialIntelligence https://t.co/htJvNu0Yl1',
#  'Great article from Jason Wolfe @GeoByHarris for using their new #deeplearning module with publically available data… '
#  'https://t.co/zLllGIVrzN',
#  'CNN Heat Maps: Saliency/Backpropagation\n'
#  '\n'
#  '#MachineLearning #DeepLearning #ConvNets via @TDataScience https://t.co/4geOQvZdNz',
#  'Getting Started With Deep Learning: Using Keras &amp; Numpy To Detect Voice Disorders - Liwaiwai #DeepLearning… '
#  'https://t.co/aDXSJpzSYB',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/YEzCCCACdT',
#  '10 Statistical Techniques #DataScientists Should Master\n'
#  'by @AISOMA_AG \n'
#  '\n'
#  'Learn more https://t.co/yMDCFYCtNw\n'
#  '\n'
#  '#AI… https://t.co/6J55ESKWun',
#  '® Deep Learning Boost Accelerates Inference Performance https://t.co/PSH8aAoyO4  #DeepLearning',
#  'Is deep learning overhyped? https://t.co/1OCY7GxZx9  #DeepLearning',
#  'Produvia is now on YouTube! We posted our first video on video generation. Subscribe on our YouTube channel to be n… '
#  'https://t.co/dKKMS0qldP',
#  'Convolutional neural networks and their application in self driving cars #DeepLearning  https://t.co/uXV9UxSEoL',
#  'Amazon: Cultural Challenges Being Addressed by Cloud - https://t.co/EeJBKLyfxd #cloud #paas #iaas #saas #dbaas… '
#  'https://t.co/gV2cCADYOa',
#  'Building a CIFAR classifier neural network with PyTorch https://t.co/53ymmlAx5R',
#  'Google Duplex AI Still Needs a Lot of Help From Humans #DeepLearning  https://t.co/xoy0Gf07Tw',
#  'Ensemble Learning\n'
#  '#AI #MachineLearning #DeepLearning\n'
#  '@MoRebaie @IAFan3 @machinlab @AliRebaie @AhmadMahmoud27\n'
#  'https://t.co/nGVp3XE7ab',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/d4c7qL3KT8',
#  'Has anyone in the #datascience community felt this way recently?\n'
#  '\n'
#  '#data #machinelearning #deeplearning #bigdata… https://t.co/BCauqyNCud',
#  'Customers Are Open To Artificial Intelligence Boosting Their Experience, Survey Shows - Forbes\n'
#  '\n'
#  'Read more here:… https://t.co/fqKof791nI',
#  'What are Symbolic and Imperative APIs in TensorFlow 2.0?\n'
#  '\n'
#  '☞ https://t.co/kaBp9CRc8O\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/OO5CjEN0ju',
#  'What are Symbolic and Imperative APIs in TensorFlow 2.0?\n'
#  '\n'
#  '☞ https://t.co/l25CziVGtm\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/qUimGnIrvW',
#  'Transforming financial reporting in insurance - Technology Record https://t.co/qYjlYuqg9c\n'
#  '\n'
#  '#DataScience… https://t.co/FbkkXl8fbT',
#  "That's how #artificialintelligence is transforming marketing - by @bhowarth @CMOAustralia |\n"
#  '\n'
#  '#AI #MachineLearning… https://t.co/Ntz3Gj6KfM',
#  "What Is #MachineLearning - A Complete Beginner's Guide\n"
#  'https://t.co/c35LKw6AUK by @BernardMarr\n'
#  '#AI #DeepLearning\n'
#  'Cc… https://t.co/YIgoSK0nkr',
#  'Convolutional neural networks and their application in self driving cars https://t.co/yzQr74F36s #DeepLearning… '
#  'https://t.co/DIfedaGoLc',
#  'Presented research on accelerating computer vision on video (https://t.co/UPHAaxgL8A) in oral/poster at CVPR 2019 t… '
#  'https://t.co/KURIqfDdAY',
#  '@AnimaAnandkumar @NvidiaAI This was the fruit of our examples effort! Trying to evangelize through many channels. M… '
#  'https://t.co/398CEwjbUx',
#  'China’s version of the “war on terror” depends less on drones and strikes by elite military units than facial recog… '
#  'https://t.co/461uWsQy21',
#  '#Report - @amazon may be working on #emotion reading device💡\n'
#  '\n'
#  'https://t.co/hzyMkQhUcQ\n'
#  '\n'
#  '#Amazon #AI #ML #DL… https://t.co/KuRCQiS0tO',
#  'Battle of Edge AI — Nvidia vs Google vs Intel\nhttps://t.co/A9oVoPhOp4\n+1 Hal2000Bot #AI #deeplearning',
#  'Google Duplex AI Still Needs a Lot of Help From Humans - ExtremeTech https://t.co/c2uO38AtdF #DeepLearning… '
#  'https://t.co/roG9QVFYFg',
#  '#AI is now taking over hedge funds.\n'
#  '\n'
#  '#ArtificialIntelligence #Finance #Fintech #MachineLearning #DeepLearning… https://t.co/PdkZmn4CVr',
#  '#AI is now taking over hedge funds.\n'
#  '\n'
#  '#ArtificialIntelligence #Finance #Fintech #MachineLearning #DeepLearning… https://t.co/pH84shJu1S',
#  'Machine learning identifies bugs that spread Chagas disease\n'
#  '_______\n'
#  '#MachineLearning #DataScience #AI… https://t.co/94RR2cWWO8',
#  'When the Music Stops: \n'
#  '\n'
#  '#AI and #Deflation \n'
#  '\n'
#  'https://t.co/Ng566DLE7o #fintech #ArtificialIntelligence… https://t.co/mACY8qCh26',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/Ig1nY6DWYM',
#  'Great articles by @frlazzeri about #DNN and applications to #Financial #Forecasting and Economic #TimeSeries.\n'
#  '\n'
#  '#ML… https://t.co/qTGM2DjPHi',
#  'PointNLM: Point Nonlocal-Means for vegetation segmentation based on middle echo point clouds… '
#  'https://t.co/gNMjCDIduU',
#  '~40,000 recent scientific articles contain the phrase #DeepLearning  in their title. As far as I understand, deep l… '
#  'https://t.co/ApgS1RBD4n',
#  'Introduction to PyTorch https://t.co/r9fvnD2C9F #deeplearning #machinelearning https://t.co/mR7j6yFXZK',
#  "Day 69 #100DaysOfMLCode Coffee + @goodfellow_ian's #DeepLearning book = better understanding of linear algebra.… "
#  'https://t.co/uGBsWA9Bpe',
#  'Physics for Deep Learning Workshop https://t.co/VmpPDkNQRB  #DeepLearning',
#  'Practical Deep Learning for Coders, v3 | https://t.co/pw9lQi0bTF course v3 https://t.co/roYpS19Lh4  #DeepLearning',
#  'The #R ecosystem is very rich &amp; constantly growing. Don’t miss out on something that can help you complete a '
#  'partic… https://t.co/2pdMPBM20L',
#  'A new mind-set for the no-collar workforce [#INFOGRAPHICS]\n'
#  ' via @Fisher85M |\n'
#  '\n'
#  ' #ArtificialIntelligence #AI… https://t.co/HPctzxJ6Y6',
#  'How to Automate Surveillance Easily with Deep Learning\n'
#  '\n'
#  '☞ https://t.co/ht1cmr5l4W\n'
#  '\n'
#  '#DeepLearning #TensorFlow https://t.co/1gLx09oFWy',
#  'Massively Multilingual Neural Machine Translation https://t.co/CUWIxHSkU0 #DeepLearning #MachineLearning #AI… '
#  'https://t.co/BORQOCbxvZ',
#  'How to Automate Surveillance Easily with Deep Learning\n'
#  '\n'
#  '☞ https://t.co/loG4Zv3ZEY\n'
#  '\n'
#  '#DeepLearning #TensorFlow https://t.co/3CbZmif2IG',
#  'DigiTrax A.I. music hip-hop beats https://t.co/YPEJJ4KiWH #ML #MachineLearning #AI #ArtificialIntelligence… '
#  'https://t.co/NCv20DLTtC',
#  'KR38R Beats incorporates A.I. in trap beats https://t.co/v6KpAPlcl2 #beats #music #hiphop #trap #musicproducer… '
#  'https://t.co/DqLj08uHjB',
#  'The 7 NLP Techniques That Will Change How You Communicate in the Future (Part II) https://t.co/3wGPdJfXdk… '
#  'https://t.co/CzSDVbBHw6',
#  'IAM Platform Curated Retweet:\n'
#  '\n'
#  'Via: https://t.co/LnIBkzdM1V\n'
#  '\n'
#  'Be a meaningful part of a global team of motivated and… https://t.co/HSjjr7DRUk',
#  'How to Become a Technical Sales Manager\n'
#  '\n'
#  '#ai #machinelearning #deeplearning #artificialintelligence #bigdata… https://t.co/XQ7t0BQrBN',
#  '*Calling all Veterans* We are currently hiring for over 30+ positions. Browse our jobs here:… '
#  'https://t.co/c7PISsYN3r',
#  'Giving my future reinforced neural network a little boost to learn to play a game https://t.co/jxMfiOOkhC',
#  'Engage #students with #inquiry and #questions. #teaching #HigherEd #DeepLearning #Wonderment #StudentEngagement '
#  'https://t.co/FODj9gbFhX',
# ...
#  '\n'
#  'Read more here:… https://t.co/7MT85Ffzt6',
#  'Business Models in #smartcities #SmartCity #BigData #AI #MachineLearning #digitaltransformation #deeplearning… '
#  'https://t.co/mcJUWmCHvb',
#  "Heroes of Deep Learning: Top Takeaways for Aspiring Data Scientists from Andrew Ng's Interview Series "
#  'https://t.co/RUAOEHUOh7  #DeepLearning',
#  'Deep Learning Indaba 2018 edition 🌍 https://t.co/Dpnx9cQQgj  #DeepLearning',
#  '3 reasons to add #DeepLearning to your #TimeSeries toolkit: \n'
#  '⭐️https://t.co/PaQ1XUUSaG\n'
#  '\n'
#  'And #NeuralNetworks for For… https://t.co/ReV3rWPN4f',
#  'Hello guys this is one of my project based on face recognition. https://t.co/bHLmx6LfQa',
#  'Ethics in #AI takes a serious twist with $188 million in funding by Stephen Schwarzman to Oxford… '
#  'https://t.co/mEoiWczKZ3',
#  "#AI's ability to explain, is helping to advance #MachineLearning and #DeepLearning effectiveness #Infographic… "
#  'https://t.co/NX1OF3wZm8',
#  'Business Models in #smartcities #SmartCity #BigData #AI #MachineLearning #digitaltransformation #deeplearning… '
#  'https://t.co/ETGkRHl8Z9',
#  'Insurance tech: should legacy applications stand in the way of innovation? - Finextra https://t.co/zWAu87j0ll… '
#  'https://t.co/mWs4zYVyAn',
#  'Driving value from AI in insurance: Delivering success with Sun Life and Scotiabank - Insurance Business Canada… '
#  'https://t.co/LQe5kRkLlW',
#  'INTERESTING READ: "DeepOps: The Lessons Deep Learning Can Learn From DevOps" https://t.co/A7jpJ73L1x #devops… '
#  'https://t.co/PmZHdq7Mvk',
#  'Car Rentals (Self Drive) Market in Asia-Pacific to 2022: Fleet Size, Rental Occasion &amp; Days, Utilization Rate '
#  'and A… https://t.co/opV4XMjaaG',
#  'A new #deepfake detection tool should keep world leaders safe for now\n'
#  '📖👉 https://t.co/JWDiHhoWTW\n'
#  'via @techreview… https://t.co/3EFUs7CoPy',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/1Rqdz4nwWK',
#  '#AIWorldGov @aiworldexpo is a few days away. Join @kath0134 &amp; @rschmelzer at #deeplearning &amp; #ML seminar Jun '
#  '24… https://t.co/PuI0A9NOgp',
#  'They see me rollin... 🚗\n'
#  '\n'
#  '#robotics #reinforcementlearning #ai #machinelearning #deeplearning #ros #robot https://t.co/A2d2VEVNC1',
#  'Why AI Will Redefine (Not Replace) Jobs https://t.co/6p0tC4ee5e #AI #ArtificialIntelligence #MachineLearning… '
#  'https://t.co/k0jw2d2Tyw',
#  'Variational Autoencoders with Tensorflow Probability Layers\n'
#  '\n'
#  '☞ https://t.co/Xjvuq61KmY\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/MbINsml4aY',
#  'Variational Autoencoders with Tensorflow Probability Layers\n'
#  '\n'
#  '☞ https://t.co/6QlhJuTsGQ\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/ZuVo43imu0',
#  'Cigna Singapore unveils telehealth service - Insurance Business ASIA https://t.co/nybG9tqdwb\n'
#  '\n'
#  '#DataScience… https://t.co/rHKixa0XnL',
#  'BRAIN TEASER! I hope this one helps you START the weekend off right! Be safe and have a great weekend! And as alway… '
#  'https://t.co/QvYl58Rx2z',
#  'deThe massive amount of data (now called #BigData) shared every second alters our way of seeing and believing thing… '
#  'https://t.co/wqM8GIWBMi',
#  'Why 85% Of Artificial Intelligence Projects Fail 06/24/2019 - MediaPost Communications\n'
#  '\n'
#  'Read more here:… https://t.co/v7oEjksnqp',
#  'The process of #deeplearning has an outsize environmental impact: training a large AI algorithm can emit as much… '
#  'https://t.co/ImMNLpHNaS',
#  'Now trying text summarisation. It might help a lot of people read books or research papers faster ie summarisation… '
#  'https://t.co/PqaSrl4Oo9',
#  '.@Google trained #deeplearning to ID malignant lung nodule in #lowdoseCT --&gt; more accurate than #humans\n'
#  'Lizzie Dorf… https://t.co/joQvEED1Pb',
#  'The #innovationmanagement Daily! https://t.co/t9uPcLQmi6 Thanks to @BiIIDutton @ennomotive #cloud #deeplearning',
#  'Understanding Value Of Correlations In  DataScience Projects https://t.co/X8fdHR3xk4 https://t.co/oeC1ltIFk7… '
#  'https://t.co/8gVjQ8Hv3P',
#  'Amazon intros new deep learning models to make Alexa more conversational #deeplearning https://t.co/PgHFVaSSGY',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/MjD4ixh1Md',
#  '83% of ODSC attendees want #MachineLearning &amp; #DeepLearning training — the most of any topic. We got the message '
#  '&amp;… https://t.co/DxfFLZOsfb',
#  'Call for Applications: Dresden Deep Learning Hackathon (9-13 September 2019) · https://t.co/vNwfti9YU4  '
#  '#DeepLearning',
#  'Eight #Storage Requirements for #AI and #DeepLearning\nhttps://t.co/9n4NtKyPYe',
#  'Global artificial intelligence market is expected to reach $71 billion by 2024 - Yahoo Finance\n'
#  '\n'
#  'Read more here:… https://t.co/WZWfoAYNj6',
#  'The Universe of Iteration\n'
#  'by @ Limo @tangleblog \n'
#  '\n'
#  'Learn more https://t.co/zDYLnGRmF4\n'
#  '\n'
#  '#AI #BigData #MachineLearning… https://t.co/LAeidDyeY6',
#  'via @RichardEudes - Top Algorithms and Methods Used by Data Scientists  https://t.co/jnMvLns4wI\xa0 #ai, '
#  '#analytics,… https://t.co/2XunkbFvT3',
#  'The ideas in DeepWalk are revolutionizing what is possible at the intersection of Graphs and Deep Learning. Check o… '
#  'https://t.co/mvh3hasOpr',
#  'Open-sourcing AI Habitat, an advanced simulation platform for embodied AI research https://t.co/Ogh68rfLbh by… '
#  'https://t.co/LCHnVu9PS3',
#  'which deep learning framework do you use?\n'
#  '#ArtificialIntelligence  #DeepLearning #NeuralNetworks @fchollet @ylecun… https://t.co/funi9kgQvw',
#  "That's an interesting in-browser PCA projector for word embeddings and other data sets! https://t.co/ljer9Egvu0… "
#  'https://t.co/pstvzXAmGJ',
#  'Outsmarting Disease — With #ArtificialIntelligence @ozy - https://t.co/KKGTnWg13R #AI #MachineLearning #ML… '
#  'https://t.co/P5cIuKKGfk',
#  'via @RichardEudes - Top Algorithms and Methods Used by Data Scientists  https://t.co/dOzspKpp5l\xa0 #ai, '
#  '#analytics,… https://t.co/yHfnCFT4ml',
#  'via @RichardEudes - Top Algorithms and Methods Used by Data Scientists  https://t.co/VO7pU707Fm\xa0 #ai, '
#  '#analytics,… https://t.co/XFLcRpWwSQ',
#  'Go further than the standard Neural Network design by understanding the Inception Network. This model has a unique… '
#  'https://t.co/spOD2U59GM',
#  'Car Rentals (Self Drive) Market in Asia-Pacific to 2022: Fleet Size, Rental Occasion &amp; Days, Utilization Rate '
#  'and A… https://t.co/owenTlgq7i',
#  'Individual Tree-Crown Detection in RGB Imagery Using Semi-Supervised Deep Learning Neural Networks '
#  'https://t.co/CgyYeoHfEX  #DeepLearning',
#  "🔥JR has been hard at work on this problem for TWO YEARS! This is an incredible accomplishment. I can't wait for him… "
#  'https://t.co/6eIR8xy7b3',
#  "What's the difference between #datascience, #machinelearning, and #artificialintelligence?\n"
#  'by @drob |\n'
#  '\n'
#  '#AI #ML… https://t.co/yT34g69zLo',
#  'Artificial Intelligence, and how it\'s aiding automated machinery, is featured on "Information Matrix ....… '
#  'https://t.co/3fqWfoqIkE',
#  'Text-to-Image Synthesis opens up many interesting applications for the future of Art! Check out this video explaini… '
#  'https://t.co/1kkqx0JZvV',
#  'Had a blast speaking at #Rework19 Applied AI Summit at SF today about #DeepLearningComingToTireIndustry; thanks to… '
#  'https://t.co/FNdrW8NsHi',
#  'StyleGAN is the current state-of-the-art for GAN image synthesis, especially in latent space control. Check out thi… '
#  'https://t.co/JUVFDlBXm5',
#  'Decomposing GAN Image Synthesis into hierarchical resolution scales has been one of the key ideas in high-resolutio… '
#  'https://t.co/12FjfntpKt',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/VNB5uk8LBW',
#  'Accelerate Deep Learning on Raspberry Pi\n\n☞ https://t.co/fcN34976ZO\n\n#DeepLearning #ai https://t.co/OlEjZ29MUi',
#  '8 ways #Insurers leverage your #BigData + #DataAnalytics to improve productivity &gt;&gt;&gt; #PwC via '
#  '@MikeQuindazzi &gt;&gt;&gt;… https://t.co/A7T4ac3Esc',
#  'Accelerate Deep Learning on Raspberry Pi\n\n☞ https://t.co/wDUQK2sDEZ\n\n#DeepLearning #ai https://t.co/iNnu1MPsrS',
#  'Making the case for more  Specialists as your  DataScience  team grows https://t.co/tJH0KCIuYP… '
#  'https://t.co/mAmvSfVI9M',
#  'Can think of @ArterysInc as @netflix for #MedicalImagaing - bringing power of #ArtificialIntelligence to #radiology… '
#  'https://t.co/vb7LPjiDra',
#  "It's worse than you think. #DeepLearning https://t.co/D74f44kgux",
#  "Radiology department can't deal with 50-100 AI models &amp; interfaces - bringing power of #ArtificialIntelligence… "
#  'https://t.co/avZFfCFAsl',
#  'With #ArtificialIntelligence #DeepLearning it is medicine powered by the power of #data -- @wilsonsonsini… '
#  'https://t.co/RCxHmMT4Sk',
#  'Proving to be true solutions for #radiology are #ArtificialIntelligence &amp; #DeepLearning @ArterysInc --… '
#  'https://t.co/wuQDslqPO1',
#  'You Are Having a Relationship With a Chatbot!\nhttps://t.co/0Pgd22sdRe\n+1 @JamesJalaPayneo #AI #deeplearning',
#  'Announcing Open Images V5 and the ICCV 2019 Open Images Challenge https://t.co/1mj4XA3hkx  #AI #MachineLearning… '
#  'https://t.co/NJDjjqr41A',
#  '#ArtificialIntelligence #DeepLearning poised to transform #radiology panel @wilsonsonsini #medicaldevice conf… '
#  'https://t.co/J3OGlBWdhk',
#  'Advances in #ArtificialIntelligence #DeepLearning poised to transform #radiology panel @wilsonsonsini… '
#  'https://t.co/fBtVVFxqc7',
#  'Want more SensorFlow fun from @lmoroney? Enroll in the https://t.co/xXmpwE13wh TensorFlow Specialization now on… '
#  'https://t.co/9HaQJpLHVo',
#  'ThreatsHub Cybersecurity News | Mozilla Fixes Second Actively-Exploited Firefox Flaw - https://t.co/Z46cZOfUJs… '
#  'https://t.co/3nz0szs04a',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/bU7WARyOrN',
#  'Really cool Innovative #DeepLearning, #AI and analysis that @aboutKP @PermanenteDocs are doing to improve health an… '
#  'https://t.co/hOaMdF7X8J',
#  '#Book #DeepLearning for Programmers\n'
#  'basically…\n'
#  'the only #DL book for programmers\n'
#  'interactive &amp; dynamic\n'
#  'step-by-step… https://t.co/Rcuw0jUTf8',
#  'AM Best Revises Outlooks to Negative for ARABIA Insurance Company s.a.l. - Business Wire https://t.co/sYcCWqewBV.… '
#  'https://t.co/4bH8GWMG7Z',
#  "Washington's #deepLearning was made to solve the #predictiveAnalytics apple crisis",
#  '#AI : A Force for Good or Bad?\n'
#  'by @VanRijmenam\n'
#  '\n'
#  'Read more https://t.co/CzwkhEa2zO\n'
#  '\n'
#  '#BigData #ArtificialIntelligence… https://t.co/kDCqFImuom',
#  'How the web has changed the way we buy #music\n'
#  '#Industry40 #ArtificialIntelligence #MachineLearning #DeepLearning… https://t.co/jn7ar9vLAf',
#  'Deep learning for cellular image analysis | Nature Methods https://t.co/AEMuHfROHc  #DeepLearning',
#  '[D] Any references for deep learning on non uniform and unstructured meshes/ grids? https://t.co/h8D5enekiw',
#  'Infographic: AI and Machine Learning – Forecasts for 2018 and Beyond #DeepLearning #AI #MachineLearning… '
#  'https://t.co/DXbvoLEmS1',
#  'Snow Peak’s Fire Pit Makes Me Like Camping Again | WIRED #travel #arianagrande #advertising #xxxtentacion… '
#  'https://t.co/6jcOQOcO5Y',
#  'Power BI and #Azure as the future of enterprise #analytics https://t.co/gAXj9VFT41 #DataScience #MachineLearning… '
#  'https://t.co/H87lZRjoCr',
#  'Submit your ABSTRACT for #CMIMI19!\n'
#  '\n'
#  'Conference on Machine Intelligence in Medical Imaging\n'
#  'Sep 22-23, 2019 | Austin,… https://t.co/d6gRdpm8pn',
#  'How to Measure Your Facebook Return on Ad Spend https://t.co/yoyXAVOIjO #socialmedia #digitalmarketing… '
#  'https://t.co/Dfg1tYXBZB',
#  'Calibrated Model-Based Deep Reinforcement Learning #DeepLearning #Statistics  https://t.co/08KxnIGVih',
#  'The 7 Jobs That Will Be Killed First by #Robots\n'
#  'by @pierrepinna @ipfconline1 |\n'
#  '\n'
#  'https://t.co/nSL1MfhCYR… https://t.co/bLNNwj1VuJ',
#  "This is a great opportunity, students!! @n_malpica 's group is the perfect place to learn about #medicalimaging and… "
#  'https://t.co/ayNCzLk6XL',
#  'Training a single #AI model can emit as much carbon as 5 cars in their lifetimes. Terrible #carbon footprint.  via… '
#  'https://t.co/87WFNEbYd9',
#  "'Artificial intelligence is threatening our #freedom. But what can we do about it?' https://t.co/lPfIvlZUEQ… "
#  'https://t.co/zF9xq5MxI4',
#  'Video: #AI, the end of #deeplearning ?\n'
#  '#DeepLearning #QuantumMechanics #MachineLearning #CognitiveComputing #RPA… https://t.co/Ca9tr4chJK',
#  'Top Algorithms and Methods Used by Data Scientists https://t.co/uQG8Sw34G1 #ai, #analytics, #artificialintelligence… '
#  'https://t.co/mF2kqSeggH',
#  'DigiTrax practical A.I. use case  https://t.co/YPEJJ4KiWH #ML #MachineLearning #AI #ArtificialIntelligence… '
#  'https://t.co/SmhB8WpVrT',
#  'KR38R Beats creates bangers https://t.co/v6KpAPlcl2 #beats #music #hiphop #trap #musicproducer #soundcloud… '
#  'https://t.co/QTV5wvfSp7',
#  '"... developing an #AI system to be interpretable is typically challenging and ambiguous." https://t.co/z9S3wNjRzi… '
#  'https://t.co/mPUZVBJbDI',
#  '4 Simple Elements of a Successful Social Media Advertising Campaign https://t.co/DBhv0Yv5q6 #socialmedia… '
#  'https://t.co/Hky1R1dK4n',
#  'Aim for Top Talent: How to Find a Great Data Scientist\n'
#  '\n'
#  '#ai #machinelearning #deeplearning #artificialintelligence… https://t.co/7z0lYk1P5V',
#  'Today, with the evolution of Neural Networks, #DeepLearning &amp; #NLP, instead of humans learning computer '
#  'languages,… https://t.co/rVSQh52YKU',
#  "OK Google, who's got the smartest speaker of them all? https://t.co/bb8d2pEzQQ #socialmedia #digitalmarketing… "
#  'https://t.co/Iu1saUFc1u',
#  '#ArtificialIntelligence and Copyright Protection https://t.co/iXRvjDp6EI #DataScience #MachineLearning… '
#  'https://t.co/5xzFUcU6IB',
#  'Amazon: 295498 Build Highly Accurate Training Datasets Using Amazon SageMaker Ground Truth -… '
#  'https://t.co/XTpTNSrWKx',
#  '🤖 #AI story: "Artificial Intelligence and the Good Society" https://t.co/zuVPJLJJKV #ArtificialIntelligence… '
#  'https://t.co/Un4GCmH3UQ',
#  '8 Questions to Ask Before Embarking on AI #DeepLearning #AI #machinelearning  https://t.co/uBYoQlcr8t',
#  '#PyCon2019 | Getting Started With #DeepLearning: Using #Keras &amp; #Numpy To Detect Voice Disorders\n'
#  '\n'
#  'https://t.co/WtfiiQYyfv',
#  '#PyCon2019 | Put Down The #DeepLearning: When Not To Use #NeuralNetworks And What To Do Instead\n'
#  '\n'
#  'https://t.co/fWf7ELruI8',
#  'How robots are helping doctors save lives in the Canadian North https://t.co/v3xggHDGOj #socialmedia… '
#  'https://t.co/9HVd2vaVA3',
#  'https://t.co/VRHsjw94fu domain name can be excellent name for AI startup,deep learning center,robotics business etc… '
#  'https://t.co/EIfy5LpY3M',
#  'Pattern89: Marketing AI Software for Your Digital Advertising\n'
#  'https://t.co/GQaHDf0FdU\n'
#  '+1 PromoBot #AI #deeplearning',
#  'VIDEO: Why the next big leap in #AI will have nothing to do with deep learning.\n'
#  '#DeepLearning #QuantumMechanics… https://t.co/1XmamoEQkv',
#  '#DeepLearning : Past and Future\n'
#  'by @gilad_maayan @Datafloq\n'
#  '\n'
#  'Go to https://t.co/wRJ2nZTxVE\n'
#  '\n'
#  '#AI #BigData… https://t.co/UUbaNYOVBB',
#  '#Logistics companies have reported replacing its classic forecasting toolset with a #deeplearning model trained wit… '
#  'https://t.co/0ZFZqvAjKO',
#  '5 Ways Artificial Intelligence Can Help Your Brand Grow https://t.co/tK6JRdIrOJ #socialmedia #digitalmarketing… '
#  'https://t.co/J10GmtNCAc',
#  'Bayesian Machine Learning in Python: A/B Testing\n'
#  '\n'
#  '☞ https://t.co/r8Bj9nM4Gp\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/H4fCwJuKPo',
#  'Bayesian Machine Learning in Python: A/B Testing\n'
#  '\n'
#  '☞ https://t.co/KxEhfXrt5U\n'
#  '\n'
#  '#TensorFlow #DeepLearning https://t.co/WPLW1haRuV',
#  '73 Mind-Blowing Sales Statistics That Will Help You Sell Smarter in 2019 https://t.co/NGcl9ZPmWQ #socialmedia… '
#  'https://t.co/T7u3Y6zqhQ']

# %% [markdown]
# # loading pretrained model and vectorizer

# %%
#Vectorizer
with open('tfidfmodel.pickle', 'rb') as f:
    vectorizer = pickle.load(f)
    
#Model
with open('classifier.pickle', 'rb') as f:
    classifier = pickle.load(f)

# %% [markdown]
# # PreProcessing the Text & Predicting the Results

# %%
total_pos = 0
total_neg = 0

for tweet in list_tweets:
    #Removing all the hyper links
    # ^ means from start and $ means from last
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    #Puntuation
    tweet = re.sub(r"\W"," ",tweet)
    #numbers
    tweet = re.sub(r"\d"," ",tweet)
    #Single alphabets 
    # ^ means from start and $ means from last
    tweet = re.sub(r"\s+[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+[a-z]$"," ",tweet)
    tweet = re.sub(r"^[a-z]\s+"," ",tweet)
    #Vaccent Spaces
    tweet = re.sub(r"\s+"," ",tweet)
    #Lower Casing
    tweet = tweet.lower()
    #Replacing Contraction with full words
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    
    #Pretty Printing
    pp.pprint(tweet)
    print(len(tweet))
    
    #Predicting The Reslts
    sent = classifier.predict(vectorizer.transform([tweet]).toarray())
    if sent[0] == 1:
        total_pos += 1
    else:
        total_neg += 1
# Out:
# 'reactions home deeplearning datascience machinelearning '
# 56
# 'as deep learning comes for medicine how do we work around its brittleness deeplearning medicine fintech '
# 104
# 'google duplex ai still needs lot of help from humans deeplearning '
# 66
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# ' datascience machinelearning datascientists bigdata data tutorial artificialintelligence deeplearning intro '
# 108
# 'itunes amp amazon paid music downloads industry artificialintelligence machinelearning deeplearning '
# 100
# 'global recorded music industry revenues industry artificialintelligence machinelearning deeplearning '
# 101
# 'the generation gap in music streaming adoption industry artificialintelligence machinelearning deeplearning '
# 108
# ' ways to turn your linkedin connections into paying clients in socialmedia '
# 75
# 'using deep learning for indoor autonomous navigation of small quad rotor need help with research '
# 97
# 'automated intent classification using deep learning deeplearning'
# 64
# 'reactions home deeplearning datascience machinelearning '
# 56
# 'so cool and sooooooo terrifying deepfake deeplearning '
# 54
# 'just today and tomorrow save on our new meap probabilistic deep learning with python use code mlsicktw at '
# 106
# 'metrics that matter measuring the effectiveness of marketing campaigns socialmedia '
# 83
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# ' deepgamingai explains how to use tensorflow objectdetection model to play the classic fps game counter strike '
# 111
# ' deeplearning affects wide range of fields from neuroscience to socialmedia and more '
# 85
# ' skills every small business marketer needs in socialmedia digitalmarketing '
# 76
# 'heroes of deep learning geoffrey hinton deeplearning'
# 52
# 'the future of ecommerce stats and trends for amp beyond infographic socialmedia '
# 80
# 'threatshub cybersecurity news movie tech review child play cybersecurity '
# 73
# 'threatshub cybersecurity news microsoft outlook for android open to xss attacks https co zvnq qlvrc '
# 100
# 'the deeplearning methods ai practitioners need to apply interest in machinelearning has exploded over the past '
# 111
# 'in this episode machine learning webinar series mention that how software engineers can switch their profession to '
# 115
# 'insurance analytics market with top eminent players like ibm microsoft oracle sap se salesforce sas institute '
# 110
# 'hey check out this service june at am chelsea mciche aguer sarri '
# 65
# 'top influencers in artificial intelligence socialmedia digitalmarketing contentmarketing '
# 89
# 'connecting asia startup ecosystem deeplearning artificialintelligence ai '
# 73
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'deep learning machine shutting off when using both gpus machinelearning'
# 71
# 'hello guys this is one of my project based on face recognition machinelearning'
# 78
# 'building cifar classifier neural network with pytorch machinelearning'
# 69
# 'giving my future reinforced neural network little boost to learn to play game machinelearning'
# 93
# 'course of the tensorflow specialization is now available tensorflow in practice course '
# 87
# ' d any references for deep learning on non uniform and unstructured meshes grids machinelearning'
# 96
# 'generative adversarial networks the story so far machinelearning'
# 64
# 'not sure if this is the correct thread gpu related machinelearning'
# 66
# 'canon medical receives fda clearance for deep convolutional neural network image reconstruction technology for ct '
# 114
# 'viral trends a practical guide for marketers socialmedia digitalmarketing '
# 74
# 'how understanding data can improve your customer service ai cx machinelearning deeplearning '
# 92
# 'how to measure your facebook return on ad spend socialmedia digitalmarketing '
# 77
# 'as deep learning comes for medicine how do we work around its brittleness deeplearning medicine fintech '
# 104
# 'ai can help pathologists reduce their turnaround time in drug discovery deeplearning ai '
# 88
# ' ai robotics ml deeplearning they re coming '
# 44
# 'advanced deep learning with keras apply deep learning techniques autoencoders gans variational autoencoders de '
# 111
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# ' bigdata ways to turn businessintelligence into business advantage by mark_samuels zdnet burnettjulian '
# 103
# 'how to recruit the best ai talent to your team ai machinelearning deeplearning artificialintelligence bigdata '
# 110
# 'ht kirkdborne top selling books in ai and machinelearning and more '
# 67
# ' ark_aung does fantastic job of bringing together some of the best resources that you need to jump into deep lea '
# 113
# 'machine learning and its scope for core engineers with cup of coffee deeplearning ai '
# 85
# ' healthcare quality improvement trends you can ignore bigdata datascience tech '
# 79
# 'hey check out this service june at pm chelsea mciche aguer sarri '
# 65
# 'not as deep as you think deeplearning machinelearning '
# 54
# 'productivity confidential artificial intelligence friend or foe podcast fast company read more here '
# 100
# 'not as deep as you think deeplearning machinelearning '
# 54
# 'connecting asia startup ecosystem deeplearning artificialintelligence ai machinelearning '
# 89
# 'global artificial intelligence market is expected to reach billion by yahoo finance read more here '
# 99
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'researchers develop ai that classifies seizures using less data by kyle_l_wiggers '
# 82
# 'the future of ai and analytics lies in helping small businesses and verticals leverage the cloud via forbes '
# 108
# 'as deep learning comes for medicine how do we work around its brittleness deeplearning '
# 87
# 'deep learning prerequisites the numpy stack in python tensorflow deeplearning '
# 78
# 'deep learning prerequisites the numpy stack in python tensorflow deeplearning '
# 78
# 'insurance tech should legacy applications stand in the way of innovation finextra https co zwau ll '
# 99
# 'it is possible to personalize user experience automate your processes and implement solutions that will give new '
# 113
# ' deeplearning what is it good for prof ankit patel riceuniversity more https co cak odbvhw '
# 91
# 'death by algorithm the age of killerrobots is closer than you think voxdotcom '
# 78
# 'social network for developers deeplearning tensorflow '
# 54
# 'why swift may be the next big thing swiftlang deeplearning python tensorflow machinelearning swift '
# 99
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# (' ai re defining the futureofwork gt gt gt wef via mikequindazzi gt gt gt artificialinteligence robotics iot '
#  'datascience ')
# 120
# 'not as deep as you think deeplearning machinelearning '
# 54
# (' ai re defining the futureofwork gt gt gt wef via mikequindazzi darshan_h_sheth gt gt gt artificialinteligence '
#  'robotics ')
# 120
# (' ai re defining the futureofwork gt gt gt wef via mikequindazzi gt gt gt artificialinteligence robotics iot '
#  'datascience ')
# 120
# 'how machinelearning works infographics by cbcurran anandsrao pwc_llp read more here '
# 84
# ' ai re defining the futureofwork gt gt gt wef via mikequindazzi gt gt gt artificialinteligence robotics iot '
# 108
# ' within the next five years every single sector will begin to use machinelearning ai and deeplearning the orga '
# 111
# ' within the next five years every single sector will begin to use machinelearning ai and deeplearning the orga '
# 111
# 'this is creepy and amazing at the same time check out also the youtube channel of ctrl_shift_face you will have '
# 112
# 'reactions home deeplearning datascience machinelearning '
# 56
# ' techstuff python leads the top data science machine learning platforms trends and analysis datascience ai '
# 107
# 'connecting asia startup ecosystem artificialintelligence deeplearning ai '
# 73
# 'hey check out this service june at pm chelsea mciche aguer sarri '
# 65
# ' data science hackathon win prizes by using machine learning to predict value of used cars futureready '
# 103
# 'reactions home deeplearning datascience machinelearning '
# 56
# 'best paper the ieee conference on computer vision and pattern recognition cvpr cvpr '
# 84
# 'ntpc to expedite training of executives using machine learning ai artificailintelligence onlinecourse '
# 102
# 'global artificial intelligence market is expected to reach billion by globenewswire read more here '
# 99
# 'vrt iainljbrown global artificial intelligence market is expected to reach billion by yahoo finance rea '
# 104
# ' language as an abstraction for hierarchical deep reinforcement learning https co xplgrc vrw '
# 93
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'want to change your life and career in just weeks welcome to magnimind academy https co lbsm djl s '
# 99
# 'implement artificial intelligence to give huge boost to your business https co xkwy xi '
# 87
# 'new amax servers aim to accelerate ai and ml workflows _____ machinelearning ai deeplearning abdsc '
# 99
# 'top selling books in ai and machinelearning and more '
# 53
# 'top selling books in ai and machinelearning and more '
# 53
# 'top selling books in ai and machinelearning and more '
# 53
# 'white house updates national artificialintelligence strategy fintech ai '
# 72
# 'connecting asia startup ecosystem deeplearning artificialintelligence ai machinelearning '
# 89
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'at redis conf redis labs introduced new module redisai the idea is that redis wants to bring together mac '
# 106
# 'as deep learning comes for medicine how do we work around its brittleness deeplearning medicine fintech '
# 104
# 'reactions home bigdata datascience machinelearning deeplearning '
# 64
# 'latest four hidden methods to make cash via revenue and advertising training small business luxurycars marketing '
# 113
# 'alessandro blassime eth zurich on digital helath information on the ethical aspects of digital technology on '
# 109
# 'as deep learning comes for medicine how do we work around its brittleness ai deeplearning medicine healthcare '
# 110
# 'very insightful presentation by a_blasimme on ethics in digitalhealth with philosophical comparison of '
# 103
# 'and we come to the end of an awesome talk by drsrinip on ai is eating the world the audience thoroughly enjoyed '
# 112
# 'deep learning method for railway and train detection follow me for more https co oswqilvtof '
# 92
# 'what do you think about seo reason toworkwithalea expert seomarketing ai iot machinelearning bigdata '
# 101
# 'hey check out this service june at pm chelsea mciche aguer sarri '
# 65
# ' netcoresolution india will win indvafg wc ai marketingautomation deeplearning netcore solutions tag fr '
# 104
# 'instagram marketing features you should be using examples socialmedia '
# 70
# 'enhancing facerecognition tools with generative face completion deeplearning machinelearning '
# 93
# 'as deep learning comes for medicine how do we work around its brittleness fintech deeplearning medicine '
# 104
# 'u s recorded music revenues by format industry artificialintelligence machinelearning deeplearning '
# 99
# 'how the web has changed the way we buy music industry artificialintelligence machinelearning deeplearning '
# 106
# 'pressure mounting on insurers to tackle silent cyberrisk s amp p global platts datascience '
# 91
# 'scientists use machine learning to improve gut disease diagnosis machines use google type algorithms on biopsy ima '
# 115
# 'artificial intelligence has recently become the focus of the public after three ups and downs with the rapid devel '
# 115
# ' opinion artificialintelligence needs to become less and less artificial ai ml '
# 79
# 'ai brings opportunity and risk to the health sector fintech insurtech healthcare '
# 81
# ' your academic education is going to land you job your self learning is going to make you wealthy '
# 98
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'amazon art of the possible leveraging machine learning to improve forecasting and governance '
# 93
# 'getting started with deep learning using keras amp numpy to detect voice disorders liwaiwai deeplearning '
# 105
# ' dogs saves us from disaster it time for machines to save us from disaster ai ml deeplearning '
# 94
# 'getting started with deep learning using keras amp numpy to detect voice disorders liwaiwai deeplearning '
# 105
# 'learning ai for product managers bigdata datascience machinelearning '
# 69
# ' deeplearning cheat sheets kdn https co tfgh sxb '
# 49
# 'learning ai for product managers bigdata datascience machinelearning '
# 69
# 'learning ai for product managers bigdata datascience machinelearning '
# 69
# 'deep learning for cellular image analysis nature methods deeplearning'
# 69
# 'report sees peril in cybercriminals looming use of ai fintech insurtech '
# 72
# 'how deeplearning can identify extract meaning from an image with text through feature extraction method ai '
# 107
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'deep learning advanced nlp and rnns deeplearning ai '
# 52
# 'deep learning advanced nlp and rnns deeplearning ai '
# 52
# ' deeplearning part not as deep as you think machinelearning '
# 60
# 'easy way to convert categorical values to numbers in python using pandas data machinelearning deeplearning '
# 107
# 'as deeplearning comes for medicine how do we work around its brittleness fintech '
# 81
# 'also for day of daysofmlcode good podcast by datafuturology with dr eric daimler ead '
# 85
# 'deep learning prerequisites linear regression in python tensorflow deeplearning '
# 80
# 'we use artificial intelligence to predict cryptocurrency market movements aiprofit artificialintelligence '
# 106
# 'understanding deep learning through neuron deletion deeplearning'
# 64
# 'deep learning prerequisites linear regression in python tensorflow deeplearning '
# 80
# 'artificial intelligence influencers mikequindazzi ipfconline alvinfoo juliosilvajr ronald_vanloon enkronos '
# 107
# 'reactions home reactions datascience machinelearning deeplearning insurance nlp robots ai iot bigdata'
# 101
# ' is decentralized stock exchange broker using multi factor systems amp deeplearning to '
# 87
# 'the year has arrived but the wave of artificial intelligence has not subsided a number of national strategic '
# 109
# 'cray powers geospatial ai revolution with breakthrough deep learning performance https co g epfxuxh '
# 100
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'top selling books in ai and machinelearning and more '
# 53
# ' deeplearning vs deep reinforcement learning algorithms in retail industry ii '
# 78
# 'we are starting today new twimlai online study group for the nlp course cs n by stanfordonline join us and be '
# 110
# 'the deep learning ai playbook strategy for disruptive artificial intelligence deeplearning ai'
# 93
# 'opentext tapping your stores of unstructured data can yield new insights opentext '
# 82
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'how to become great cdo ai machinelearning deeplearning artificialintelligence bigdata datascience '
# 99
# 'our paper titled stealing neural networks via timing side channels has been accepted at international conference '
# 113
# 'global artificial intelligence market is expected to reach billion by globenewswire read more here '
# 99
# 'god light comes to us not through ceremonies good times he comes into pained heart tuff times '
# 94
# ' actionable takeaways from the seo ranking factors ai ar vr blockchain drones robotics iot dprinting '
# 101
# 'deepfake buster ai beating ai really cool deeplearning '
# 55
# 'reinforcement learning with pytorch deeplearning ai '
# 52
# 'reinforcement learning with pytorch deeplearning ai '
# 52
# 'mit teaching robots to combine sight and touch deeplearning machinelearning ai '
# 79
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'modernizing insurance data platforms to improve governance and enrich customer experience gigaom '
# 97
# 'not sure if this is the correct thread gpu related '
# 51
# 'the innovation startup deeplearning artificialintelligence ai machinelearning '
# 78
# ' netcoresolution indiaaaa indiaaaa india will win the match netcoresolution indvafg wc ai '
# 90
# ' regtech wants to improve behavior monitoring ai gt gt gt pwc via mikequindazzi gt gt gt fintech insurtech iot '
# 111
# ' regtech wants to improve behavior monitoring ai gt gt gt pwc via mikequindazzi gt gt gt fintech insurtech iot '
# 111
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# ' regtech wants to improve behavior monitoring ai gt gt gt pwc via mikequindazzi gt gt gt fintech insurtech iot '
# 111
# 'asia times ai accelerates development of limitless fusion energy article deeplearning '
# 86
# 'open domain question answering with deeppavlov deeppavlov medium deeplearning '
# 78
# 'and now this understanding deep learning tech technology datascience '
# 69
# 'how to design ai tools for the workplace according to google ai machinelearning nlp '
# 84
# 'ahrvodeex is decentralized stock exchange broker using multi factor systems amp deeplearning to create equity '
# 110
# ' farmersweeklynz we have had tremendous response to this article and many offers to assist sheepnn deeplearning '
# 112
# 'simple introduction to neural networks towards data science deeplearning '
# 73
# 'how do you define unfair bias in artificial intelligence colinapriest datarobot ai machinelearning '
# 99
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'artificial intelligence spotting fake news and digital equity what to see at iste education week read '
# 102
# 'business leaders have written letter urging the next prime minister to commit to completing hs deeplearning '
# 108
# 'how scientists are fighting back against the coming deepfake sh show deepfake neuralnetworks deeplearning '
# 106
# 'looking forward to our very first devsprint with students so excited about the young speakers that will be sharin '
# 114
# 'how blockchain can transform artificialintelligence by dash_bouquet hackernoon ai '
# 82
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'the history evolution and growth of deeplearning via analyticsinme ai '
# 70
# 'top story ronald_vanloon a new mind set for the no collar workforce infographics via fisher m '
# 94
# 'deep learning for student competitions deeplearning'
# 51
# 'online courses complete data science amp machine learning bootcamp gt https co lcyyuxgot '
# 89
# 'artificial intelligence explained what are generative adversarial networks gans ai ml '
# 86
# ' robotic arm learns to fly boeing via ai software via mikequindazzi ai robotics autonomous '
# 91
# 'i going through process where my own mind is lying to me don believe it true check out marvin minsky so '
# 104
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'i have many questions how recent were the mammograms from the same imaging manufacturers or different ai goes '
# 110
# 'machine learning and its scope for core engineers with cup of coffee hal bot ai deeplearning'
# 92
# 'cloud based image classification service is not robust to simple transformations a forgotten battlefield '
# 105
# 'sample fintech landscape by type and segment gt gt gt statistacharts via mikequindazzi gt gt gt ai machinelearning '
# 115
# 'free coupons discount sql mysql for data analytics and business intelligence courses gt https co iyimrmk ld '
# 108
# 'top story ronald_vanloon a new mind set for the no collar workforce infographics via fisher m '
# 94
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'sample fintech landscape by type and segment gt gt gt statistacharts via mikequindazzi gt gt gt ai machinelearning '
# 115
# 'artificial intelligence generates humans faces based on their voices ai ml dl '
# 78
# 'not enough labeled training data is huge barrier for the efficiency of deeplearning here are strategies for '
# 108
# 'distributed deep learning pipelines with pyspark and keras by tdatascience deeplearning'
# 87
# 'udemy free discount deep learning with tensorflow udemycoupon gt datascience '
# 77
# 'new online courses data science deep learning in python gt explore python '
# 74
# 'threatshub cybersecurity news this week in security news cyberespionage campaigns and botnet malware '
# 101
# 'threatshub cybersecurity news mobok malware hides in photo editors on google play siphons cash '
# 95
# 'why artificialintelligence is about to make ransomware hackattacks even scarier https co yn s gri '
# 98
# 'mit deep learning basics introduction and overview with tensorflow deeplearning '
# 80
# 'mit deep learning basics introduction and overview with tensorflow deeplearning '
# 80
# 'a beginner guide to generative adversarial networks gans deeplearning machinelearning '
# 86
# 'making deep learning useful for small life science datasets deeplearning'
# 72
# ' ai storage machinelearning deeplearning and storage needs via swisscognitive '
# 78
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'artificial intelligence primer for physicians ai machinelearning deeplearning '
# 78
# 'put down the deep learning when not to use neural networks and what to do instead liwaiwai neuralnetworks '
# 106
# 'the dirty expensive secret of artificialintelligence and machinelearning fintech ai '
# 84
# 'cloudexpo new york spring sponsorship opportunities open hybridcloud bigdata ai iot smartcities aiops '
# 102
# 'keras tutorial deep learning in python deeplearning'
# 51
# ' another triple for the deepracer league brings more world records and the first female winner '
# 95
# ' deeplearning enables high quality and high throughput prediction of enzyme commission numbers lifesciences '
# 108
# 'how google uses reinforcementlearning to train ai agents in the most popular sport in the world '
# 96
# 'calibrated model based deep reinforcement learning deeplearning statistics '
# 75
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'digitrax a i blockcha i music ml machinelearning ai artificialintelligence '
# 75
# 'kr r beats sets the stage for the future of hip hop production beats music hiphop trap '
# 87
# 'hiring great technical sales manager ai machinelearning deeplearning artificialintelligence bigdata '
# 100
# 'so google is now able to do speech speech language translation directly without using text that neat good job '
# 110
# 'aon targets improved customer engagement with hi marley partnership reinsurance news https co cs olliuad '
# 105
# 'google latest languagemachine puts emphasis back on language fintech zdnet '
# 75
# 'deepfake beta the bad news this ai can turn one photo of you into talking head good news there is none '
# 103
# 'alexa gone bad when ai assistants turn on us fintech cybersecurity iot '
# 71
# ' deeplearning has made it easier for anyone to forge convincing misinformation but just how easy researchers at g '
# 114
# 'threatshub cybersecurity news data of oregonians exposed after nine dhs employees fell for phishing attack '
# 107
# 'threatshub cybersecurity news digi dosh exchange coinbase someone tried to pwn our staff via this week firefox '
# 111
# 'ensemble machine learning in python random forest adaboost tensorflow deeplearning '
# 83
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'ensemble machine learning in python random forest adaboost tensorflow deeplearning '
# 83
# ' games for change festival deep learning through games deeplearning'
# 67
# 'policy expert forays into motor insurance insurance business uk datascience '
# 76
# 'oasis loss modeling framework available on fractal advanced insurance decision platform prnewswire '
# 99
# 'driving value from ai in insurance delivering success with sun life and scotiabank insurance business canada '
# 109
# 'new analysis report on insurance it spending market market research updates https co zgzwx ilzi '
# 96
# 'cvpr showcased ai that can visualize hidden objects and see around corners https co o x xndf '
# 93
# 'ht kirkdborne see how ibm ai automatically generates creative captions for images by '
# 85
# 'see how ibm ai automatically generates creative captions for images by kyle_l_wiggers '
# 86
# 'why digitaltransformation won succeed without cultural change by naullyn digital '
# 81
# 'bring on the ai revolution amp its shake up of academia fintech insurtech '
# 74
# 'linear regression dive into deeplearning ai machinelearning datascience cc '
# 75
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'how to use the alexa app in windows hal bot ai deeplearning'
# 59
# 'ai amp deep learning summits in san francisco what did you miss deeplearning ai artificialintelligence'
# 102
# 'researchers teach ai to write haikus fintech artificialintelligence machinelearning '
# 84
# 'introducing deep spreadsheets with xlnet state of the art deep learning in excel happyfriday deeplearning '
# 106
# ' machinelearning engineers get passionate about that python library datascience deeplearning ai '
# 96
# 'extracting campaign finance data from gnarly pdfs using deeplearning '
# 69
# 'ai can now detect deepfakes by looking for weird facial movements techbot ai deeplearning'
# 89
# 'abc free datasets for geometric deep learning ai³ theory practice business medium https co gesu sg ao '
# 102
# 'getting started with deep learning using keras amp numpy to detect voice disorders liwaiwai deeplearning '
# 105
# 'how to design ai tools for the workplace according to google fintech insurtech '
# 79
# 'how understanding data can improve your customer service ai cx machinelearning deeplearning '
# 92
# 'train and deploy keras models with tensorflow and apache mxnet on amazon sagemaker machinelearning deeplearning '
# 112
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'am best downgrades credit ratings of arabia insurance company jordan business wire https co auewskha '
# 101
# 'jeff scheaffer relates some of the applications cisco is using with various ai related tools '
# 93
# 'spotting objects amid clutter conventional techniques that try to pick out objects from such clouds of dots or '
# 111
# 'ht kirkdborne learning ai for product managers bigdata datascience '
# 67
# 'word of the day artificial intelligence check out our apparel datascience artificialintelligence '
# 97
# 'ai and deeplearning for automotive applications bigdata analytics machinelearning datascience ai iot iiot '
# 106
# 'learning ai for product managers bigdata datascience machinelearning '
# 69
# 'a new set of images that fool ai could help make it more hackerproof fintech '
# 77
# ' amazonfashion new visualsearch tool aims to boost apparel sales stylesnap fashion '
# 83
# 'put down the deep learning when not to use neural networks and what to do instead liwaiwai neuralnetworks '
# 106
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'illustrated guide to lstm and gru bigdata analytics deeplearning machinelearning datascience ai iot '
# 100
# 'data pre processing for deep learning models deep learning with keras part deeplearning '
# 88
# 'ht kirkdborne this week featured articles and resources in machinelearning datascience ai statistics and '
# 105
# ' techstuff microsoft to train lakh students at ai digital labs in india the week ai ml neuralnetworks '
# 102
# 'this week featured articles and resources in machinelearning datascience ai statistics and more at '
# 99
# 'yolo object detection in matlab start to finish towards data science deeplearning '
# 82
# 'good one for federated learning machinelearning deeplearning artificialintelligence '
# 84
# 'great article from jason wolfe geobyharris for using their new deeplearning module with publically available data '
# 114
# 'cnn heat maps saliency backpropagation machinelearning deeplearning convnets via tdatascience '
# 94
# 'getting started with deep learning using keras amp numpy to detect voice disorders liwaiwai deeplearning '
# 105
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# ' statistical techniques datascientists should master by aisoma_ag learn more ai '
# 80
# ' deep learning boost accelerates inference performance deeplearning'
# 67
# 'is deep learning overhyped deeplearning'
# 39
# 'produvia is now on youtube we posted our first video on video generation subscribe on our youtube channel to be '
# 112
# 'convolutional neural networks and their application in self driving cars deeplearning '
# 86
# 'amazon cultural challenges being addressed by cloud cloud paas iaas saas dbaas '
# 79
# 'building cifar classifier neural network with pytorch '
# 54
# 'google duplex ai still needs lot of help from humans deeplearning '
# 66
# 'ensemble learning ai machinelearning deeplearning morebaie iafan machinlab alirebaie ahmadmahmoud '
# 98
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'has anyone in the datascience community felt this way recently data machinelearning deeplearning bigdata '
# 105
# 'customers are open to artificial intelligence boosting their experience survey shows forbes read more here '
# 107
# 'what are symbolic and imperative apis in tensorflow tensorflow deeplearning '
# 76
# 'what are symbolic and imperative apis in tensorflow tensorflow deeplearning '
# 76
# 'transforming financial reporting in insurance technology record datascience '
# 76
# 'that how artificialintelligence is transforming marketing by bhowarth cmoaustralia ai machinelearning '
# 102
# 'what is machinelearning a complete beginner guide by bernardmarr ai deeplearning cc '
# 84
# 'convolutional neural networks and their application in self driving cars deeplearning '
# 86
# 'presented research on accelerating computer vision on video https co uphaaxgl a in oral poster at cvpr '
# 103
# ' animaanandkumar nvidiaai this was the fruit of our examples effort trying to evangelize through many channels m '
# 113
# 'china version of the war on terror depends less on drones and strikes by elite military units than facial recog '
# 112
# ' report amazon may be working on emotion reading device amazon ai ml dl '
# 72
# 'battle of edge ai nvidia vs google vs intel hal bot ai deeplearning'
# 67
# 'google duplex ai still needs lot of help from humans extremetech deeplearning '
# 78
# ' ai is now taking over hedge funds artificialintelligence finance fintech machinelearning deeplearning '
# 103
# ' ai is now taking over hedge funds artificialintelligence finance fintech machinelearning deeplearning '
# 103
# 'machine learning identifies bugs that spread chagas disease _______ machinelearning datascience ai '
# 99
# 'when the music stops ai and deflation fintech artificialintelligence '
# 69
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'great articles by frlazzeri about dnn and applications to financial forecasting and economic timeseries ml '
# 107
# 'pointnlm point nonlocal means for vegetation segmentation based on middle echo point clouds '
# 92
# ' recent scientific articles contain the phrase deeplearning in their title as far as i understand deep '
# 103
# 'introduction to pytorch deeplearning machinelearning '
# 53
# 'day daysofmlcode coffee goodfellow_ian deeplearning book better understanding of linear algebra '
# 96
# 'physics for deep learning workshop deeplearning'
# 47
# 'practical deep learning for coders course deeplearning'
# 54
# 'the r ecosystem is very rich amp constantly growing don miss out on something that can help you complete partic '
# 112
# 'a new mind set for the no collar workforce infographics via fisher m artificialintelligence ai '
# 95
# 'how to automate surveillance easily with deep learning deeplearning tensorflow '
# 79
# 'massively multilingual neural machine translation deeplearning machinelearning ai '
# 82
# 'how to automate surveillance easily with deep learning deeplearning tensorflow '
# 79
# 'digitrax a i music hip hop beats ml machinelearning ai artificialintelligence '
# 78
# 'kr r beats incorporates a i in trap beats beats music hiphop trap musicproducer '
# 80
# 'the nlp techniques that will change how you communicate in the future part ii https co wgpdjfxdk '
# 97
# 'iam platform curated retweet via be meaningful part of global team of motivated and '
# 84
# 'how to become technical sales manager ai machinelearning deeplearning artificialintelligence bigdata '
# 101
# ' calling all veterans we are currently hiring for over positions browse our jobs here '
# 86
# 'giving my future reinforced neural network little boost to learn to play game '
# 78
# 'engage students with inquiry and questions teaching highered deeplearning wonderment studentengagement '
# 103
# ' deeplearning algorithm trained on synthetic data outperforms state of the art network trained on real images gt gt '
# 116
# ' ways insurers leverage your bigdata dataanalytics to improve productivity gt gt gt pwc via mikequindazzi gt gt gt '
# 115
# ' countries most prepared for automation and the futureofwork gt gt gt theeconomist via mikequindazi gt gt gt ai '
# 112
# ' ai ability to explain is helping to advance machinelearning and deeplearning effectiveness gt gt gt infographic gt '
# 116
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'introduction to pytorch biggraph with examples machinelearning deeplearning datascience pytorch via '
# 100
# 'an excellent read ai trends for spirosmargaris jimmarous xbond ahier topcybernews psb_dc '
# 89
# 'data scientists taming artificial intelligence actuarial post datascience '
# 74
# ' deeplearningai_ the specialization is insightful the first courses teach how to build deep neuralnetworks with '
# 112
# 'introducing custom deep learning models build your own custom neural network based pattern match models to identif '
# 115
# ' deep fakevideos are now coming by ronald_vanloon machinelearning ml deeplearning dl algorithm ai '
# 98
# 'algorithms need to be challenged deeplearning ai machinelearning datascience unlockaipotential '
# 95
# 'how understanding data can improve your customer service ai cx machinelearning deeplearning '
# 92
# 'five major ai trends to watch in the years ahead by ssi_innovations iot bigdata machinelearning '
# 96
# 'am besttv at the iis global forum insurers biggest risk is losing touch with the customer business wire '
# 104
# 'foster explainability of deeplearning model nice work nlproc bert '
# 66
# ' techstuff lockheed unveils object recognition tool with deep learning capability maria demaree quoted govconwi '
# 112
# 'deep learning and nlp a z how to create chatbot deeplearning'
# 60
# 'jeff scheaffer relates some of the applications cisco is using with various ai related tools '
# 93
# 'part of how to build and amazing contextual chatbot using tensorflow series see how to build neural network fr '
# 111
# ' ucla bioengineers are able to produce high resolution pictures from low resolution images of fluorescence '
# 107
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'learn how to create deeper level of understanding amp responses to yourself amp from others our nlp practitioner tra '
# 117
# 'how understanding data can improve your customer service ai cx machinelearning deeplearning '
# 92
# 'another revelation of the fake face driven by deepfake ai technology this battle gonna last for long period '
# 108
# 'how relevant is kaggle experience to developing commercial ai hal bot ai deeplearning'
# 85
# 'will artificialintelligence be recruiter new best friend fintech futureofwork '
# 78
# ' ai has entered its golden age and it will change every industry by wef read full article here '
# 95
# 'lastline ceo john dilullo explores three particularly nasty attacks that we all would miss if it weren for '
# 107
# 'has someone built deeplearning surgical laser robot that can make me skinnier based on old photos i upload to its '
# 114
# 'deep learning for search deeplearning'
# 37
# 'the sfapvnc bird houses are coming together the students are getting excited to take home their bird habitat and '
# 113
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'how machine learning helps siri and alexa understand you global impact artificialintelligence '
# 94
# 'acrobat robot future machinelearning ml artificialintelligence ai tech ir deeplearning '
# 87
# ' trending financial services sector forges ahead with artificial intelligence zdnet ai ml neuralnetworks '
# 105
# 'the future of work one more example of how robotics saves lives digitaltransformation transformaciondigital '
# 108
# 'business models in smartcities smartcity bigdata ai machinelearning digitaltransformation deeplearning '
# 103
# 'forget killer robots ai is heading in much more conducive direction ai deeplearning deepfake beyonce '
# 101
# 'the future of work ai data sculptures turning invisible into visible digitaltransformation transformaciondigital '
# 113
# 'five ways you re already using machinelearning a day with ai deeplearning bigdata fintech insurtech martech '
# 108
# 'applying automl to transformer architectures deeplearning ai automated '
# 71
# 'checkout my latest post on tdatascience about distributed deep learning pipelines with pyspark and keras '
# 105
# 'global artificial intelligence market is expected to reach billion by globenewswire read more here '
# 99
# 'business models in smartcities smartcity bigdata ai machinelearning digitaltransformation deeplearning '
# 103
# 'heroes of deep learning top takeaways for aspiring data scientists from andrew ng interview series deeplearning'
# 111
# 'deep learning indaba edition deeplearning'
# 41
# ' reasons to add deeplearning to your timeseries toolkit https co paq xuusag and neuralnetworks for for '
# 103
# 'hello guys this is one of my project based on face recognition '
# 63
# 'ethics in ai takes serious twist with million in funding by stephen schwarzman to oxford '
# 89
# ' ai ability to explain is helping to advance machinelearning and deeplearning effectiveness infographic '
# 104
# 'business models in smartcities smartcity bigdata ai machinelearning digitaltransformation deeplearning '
# 103
# 'insurance tech should legacy applications stand in the way of innovation finextra https co zwau ll '
# 99
# 'driving value from ai in insurance delivering success with sun life and scotiabank insurance business canada '
# 109
# 'interesting read deepops the lessons deep learning can learn from devops devops '
# 80
# 'car rentals self drive market in asia pacific to fleet size rental occasion amp days utilization rate and a '
# 108
# 'a new deepfake detection tool should keep world leaders safe for now via techreview '
# 84
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# ' aiworldgov aiworldexpo is few days away join kath amp rschmelzer at deeplearning amp ml seminar jun '
# 101
# 'they see me rollin robotics reinforcementlearning ai machinelearning deeplearning ros robot '
# 92
# 'why ai will redefine not replace jobs ai artificialintelligence machinelearning '
# 80
# 'variational autoencoders with tensorflow probability layers tensorflow deeplearning '
# 84
# 'variational autoencoders with tensorflow probability layers tensorflow deeplearning '
# 84
# 'cigna singapore unveils telehealth service insurance business asia datascience '
# 79
# 'brain teaser i hope this one helps you start the weekend off right be safe and have great weekend and as alway '
# 111
# 'dethe massive amount of data now called bigdata shared every second alters our way of seeing and believing thing '
# 113
# 'why of artificial intelligence projects fail mediapost communications read more here '
# 85
# 'the process of deeplearning has an outsize environmental impact training large ai algorithm can emit as much '
# 109
# 'now trying text summarisation it might help lot of people read books or research papers faster ie summarisation '
# 112
# ' google trained deeplearning to id malignant lung nodule in lowdosect gt more accurate than humans lizzie dorf '
# 111
# 'the innovationmanagement daily thanks to biiidutton ennomotive cloud deeplearning'
# 81
# 'understanding value of correlations in datascience projects https co oec ltifk '
# 79
# 'amazon intros new deep learning models to make alexa more conversational deeplearning '
# 86
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# ' of odsc attendees want machinelearning amp deeplearning training the most of any topic we got the message amp '
# 111
# 'call for applications dresden deep learning hackathon september deeplearning'
# 76
# 'eight storage requirements for ai and deeplearning '
# 51
# 'global artificial intelligence market is expected to reach billion by yahoo finance read more here '
# 99
# 'the universe of iteration by limo tangleblog learn more ai bigdata machinelearning '
# 83
# 'via richardeudes top algorithms and methods used by data scientists ai analytics '
# 81
# 'the ideas in deepwalk are revolutionizing what is possible at the intersection of graphs and deep learning check '
# 113
# 'open sourcing ai habitat an advanced simulation platform for embodied ai research by '
# 85
# 'which deep learning framework do you use artificialintelligence deeplearning neuralnetworks fchollet ylecun '
# 108
# 'that an interesting in browser pca projector for word embeddings and other data sets https co ljer egvu '
# 104
# 'outsmarting disease with artificialintelligence ozy ai machinelearning ml '
# 74
# 'via richardeudes top algorithms and methods used by data scientists ai analytics '
# 81
# 'via richardeudes top algorithms and methods used by data scientists ai analytics '
# 81
# 'go further than the standard neural network design by understanding the inception network this model has unique '
# 112
# 'car rentals self drive market in asia pacific to fleet size rental occasion amp days utilization rate and a '
# 108
# 'individual tree crown detection in rgb imagery using semi supervised deep learning neural networks deeplearning'
# 111
# ' jr has been hard at work on this problem for two years this is an incredible accomplishment i can wait for him '
# 112
# 'what the difference between datascience machinelearning and artificialintelligence by drob ai ml '
# 97
# 'artificial intelligence and how it aiding automated machinery is featured on information matrix '
# 96
# 'text to image synthesis opens up many interesting applications for the future of art check out this video explaini '
# 115
# 'had blast speaking at rework applied ai summit at sf today about deeplearningcomingtotireindustry thanks to '
# 108
# 'stylegan is the current state of the art for gan image synthesis especially in latent space control check out thi '
# 114
# 'decomposing gan image synthesis into hierarchical resolution scales has been one of the key ideas in high resolutio '
# 116
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'accelerate deep learning on raspberry pi deeplearning ai '
# 57
# ' ways insurers leverage your bigdata dataanalytics to improve productivity gt gt gt pwc via mikequindazzi gt gt gt '
# 115
# 'accelerate deep learning on raspberry pi deeplearning ai '
# 57
# 'making the case for more specialists as your datascience team grows https co tjh kciuyp '
# 88
# 'can think of arterysinc as netflix for medicalimagaing bringing power of artificialintelligence to radiology '
# 109
# 'it worse than you think deeplearning '
# 37
# 'radiology department can deal with ai models amp interfaces bringing power of artificialintelligence '
# 101
# 'with artificialintelligence deeplearning it is medicine powered by the power of data wilsonsonsini '
# 99
# 'proving to be true solutions for radiology are artificialintelligence amp deeplearning arterysinc '
# 98
# 'you are having relationship with chatbot jamesjalapayneo ai deeplearning'
# 72
# 'announcing open images v and the iccv open images challenge ai machinelearning '
# 79
# ' artificialintelligence deeplearning poised to transform radiology panel wilsonsonsini medicaldevice conf '
# 106
# 'advances in artificialintelligence deeplearning poised to transform radiology panel wilsonsonsini '
# 98
# 'want more sensorflow fun from lmoroney enroll in the tensorflow specialization now on '
# 86
# 'threatshub cybersecurity news mozilla fixes second actively exploited firefox flaw https co z czofujs '
# 102
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# 'really cool innovative deeplearning ai and analysis that aboutkp permanentedocs are doing to improve health an '
# 111
# ' book deeplearning for programmers basically the only dl book for programmers interactive amp dynamic step by step '
# 115
# 'am best revises outlooks to negative for arabia insurance company a business wire https co syccwqewbv '
# 102
# 'washington deeplearning was made to solve the predictiveanalytics apple crisis'
# 78
# ' ai a force for good or bad by vanrijmenam read more bigdata artificialintelligence '
# 84
# 'how the web has changed the way we buy music industry artificialintelligence machinelearning deeplearning '
# 106
# 'deep learning for cellular image analysis nature methods deeplearning'
# 69
# ' d any references for deep learning on non uniform and unstructured meshes grids '
# 81
# 'infographic ai and machine learning forecasts for and beyond deeplearning ai machinelearning '
# 93
# 'snow peak fire pit makes me like camping again wired travel arianagrande advertising xxxtentacion '
# 98
# 'power bi and azure as the future of enterprise analytics datascience machinelearning '
# 85
# 'submit your abstract for cmimi conference on machine intelligence in medical imaging sep austin '
# 96
# 'how to measure your facebook return on ad spend socialmedia digitalmarketing '
# 77
# 'calibrated model based deep reinforcement learning deeplearning statistics '
# 75
# 'the jobs that will be killed first by robots by pierrepinna ipfconline https co nsl mfhcyr '
# 91
# 'this is great opportunity students n_malpica group is the perfect place to learn about medicalimaging and '
# 106
# 'training single ai model can emit as much carbon as cars in their lifetimes terrible carbon footprint via '
# 106
# ' artificial intelligence is threatening our freedom but what can we do about it https co lpfivlzueq '
# 100
# 'video ai the end of deeplearning deeplearning quantummechanics machinelearning cognitivecomputing rpa '
# 102
# 'top algorithms and methods used by data scientists ai analytics artificialintelligence '
# 87
# 'digitrax practical a i use case ml machinelearning ai artificialintelligence '
# 77
# 'kr r beats creates bangers beats music hiphop trap musicproducer soundcloud '
# 76
# ' developing an ai system to be interpretable is typically challenging and ambiguous https co s wnjrzi '
# 102
# ' simple elements of successful social media advertising campaign socialmedia '
# 77
# 'aim for top talent how to find great data scientist ai machinelearning deeplearning artificialintelligence '
# 107
# 'today with the evolution of neural networks deeplearning amp nlp instead of humans learning computer languages '
# 111
# 'ok google who got the smartest speaker of them all socialmedia digitalmarketing '
# 80
# ' artificialintelligence and copyright protection datascience machinelearning '
# 77
# 'amazon build highly accurate training datasets using amazon sagemaker ground truth '
# 83
# ' ai story artificial intelligence and the good society artificialintelligence '
# 78
# ' questions to ask before embarking on ai deeplearning ai machinelearning '
# 73
# ' pycon getting started with deeplearning using keras amp numpy to detect voice disorders '
# 89
# ' pycon put down the deeplearning when not to use neuralnetworks and what to do instead '
# 87
# 'how robots are helping doctors save lives in the canadian north socialmedia '
# 76
# ' domain name can be excellent name for ai startup deep learning center robotics business etc '
# 93
# 'pattern marketing ai software for your digital advertising promobot ai deeplearning'
# 83
# 'video why the next big leap in ai will have nothing to do with deep learning deeplearning quantummechanics '
# 107
# ' deeplearning past and future by gilad_maayan datafloq go to ai bigdata '
# 72
# ' logistics companies have reported replacing its classic forecasting toolset with deeplearning model trained wit '
# 113
# ' ways artificial intelligence can help your brand grow socialmedia digitalmarketing '
# 84
# 'bayesian machine learning in python a b testing tensorflow deeplearning '
# 72
# 'bayesian machine learning in python a b testing tensorflow deeplearning '
# 72
# ' mind blowing sales statistics that will help you sell smarter in socialmedia '
# 78

# %%
print("Positive Reviews: {}".format(total_pos))
print("Negative Reviews: {}".format(total_neg))
# Out:
# Positive Reviews: 372
# Negative Reviews: 128

# %%
#Accuracy
print("Accuracy score is {}%".format((total_pos / 500)*100))
# Out:
# Accuracy score is 74.4%

# %% [markdown]
# # Plotting The Results

# %%
# Visualizing the results
objects = ['Positive','Negative']
y_pos = np.arange(len(objects))

plt.bar(y_pos,[total_pos,total_neg],alpha=0.5)
plt.xticks(y_pos,objects)
plt.ylabel('Number')
plt.title('Number of Postive and Negative Tweets
